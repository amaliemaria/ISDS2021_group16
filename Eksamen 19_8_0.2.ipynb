# %%
# Python Script to Extract tweets of a 
# particular Hashtag using Tweepy and Pandas

# import modules
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import datetime
import tweepy
import json
import pandas as pd
import csv
import re #regular expression
from textblob import TextBlob
import string
import preprocessor as p
import os
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\sasha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sasha\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f"Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text:{ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")
    print(f"Date:{ith_tweet[9]}")

# %%
#importer dansk som sprog
#pip install afinn
from afinn import Afinn
afinn = Afinn(language='da')

# %%
# function to perform data extraction
def scrape(words, date_since, numtweet):
      
    # Creating DataFrame using pandas
    db = pd.DataFrame(columns=['username', 'description', 'location', 'following',
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags', 'date'])
      
    # We are using .Cursor() to search through twitter for the required tweets.
    # The number of tweets can be restricted using .items(number of tweets)
    tweets = tweepy.Cursor(api.search, q=words, lang="da",
                           since=date_since, tweet_mode='extended').items(numtweet)
     
    # .Cursor() returns an iterable object. Each item in 
    # the iterator has various attributes that you can access to 
    # get information about each tweet
    list_tweets = [tweet for tweet in tweets]
      
    # Counter to maintain Tweet Count
    i = 1  
      
    # we will iterate over each tweet in the list for extracting information about each tweet
    for tweet in list_tweets:
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
        date = tweet.created_at
          
        # Retweets can be distinguished by a retweeted_status attribute,
        # in case it is an invalid reference, except block will be executed
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
          
        # Here we are appending all the extracted information in the DataFrame
        ith_tweet = [username, description, location, following,
                     followers, totaltweets, retweetcount, text, hashtext, date]
        db.loc[len(db)] = ith_tweet
        
          
        # Function call to print tweet data on screen
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'df3.csv'
    
    #filename df1= COVID19 Covid19dk coronadk
    #filename df2= (dkpol:Covid19dk) OR (dkpol:coronadk) OR (dkpol:COVID19)
    #filename df3= (dkmedier:Covid19dk) OR (dkmedier:coronadk) OR (dkmedier:COVID19)
      
    # we will save our database as a CSV file.
    db.to_csv(filename)
  
  
if __name__ == '__main__':
      
    # Enter your own credentials obtained 
    # from your developer account
    consumer_key = "5Lc4sTEI4Iu76e5NTUPonfiqA"
    consumer_secret = "VxE3SEPYgIGzvj3t3XEe77vNcpYAeOMKm3QpOfqa4ZO7y5tkEi"
    access_key = "1183298126523838464-AmxGW3Jn6Frrff281wewWSB386sEQ0"
    access_secret = "P36t9VcCYCWgn0QIdotXe2R4tbOz3rSeSHpuz0s5NkNz2"
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
      
    # Enter Hashtag and initial date
    print("Enter Twitter HashTag to search for")
    words = input()
    print("Enter Date since The Tweets are required in yyyy-mm--dd")
    date_since = input()
      
    # number of tweets you want to extract in one run
    numtweet = 10000
    scrape(words, date_since, numtweet)
    print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# (dkmedier:Covid19dk) OR (dkmedier:coronadk) OR (dkmedier:COVID19)
# Enter Date since The Tweets are required in yyyy-mm--dd
# 2021-01-01
#
# Tweet 1:
# Username:TrockHempler
# Description:MA in Philosophy. Philosophy, existentialism, ethics, politics, media, art, technology, current events https://t.co/FCTJaBl5Aw +4528920928
# Location:København, Danmark
# Following Count:4927
# Follower Count:6416
# Total Tweets:2458
# Retweet Count:0
# Tweet Text:https://t.co/WyB1WsjH0w
# Gælder også i Dk! #dkpol #dkmedier #covid19dk #DeltaVariant
# Mennesker er så vidunderligt forskellige og dog gjort af samme stof
# Hashtags Used:['dkpol', 'dkmedier', 'covid19dk', 'DeltaVariant']
# Date:2021-08-18 19:28:46
#
# Tweet 2:
# Username:transceiverfreq
# Description:xi=aixi'-(d+ai0+ai1)xi+rxi(fi-Φ ) | Freelance Research | Infosec | Professional 10th woman | Websnedker | 微博：zzz大梦想家 ☆ [Videnskab, klima & ugens kortfilm]
# Location:Frederiksberg, Denmark
# Following Count:340
# Follower Count:1088
# Total Tweets:44936
# Retweet Count:7
# Tweet Text:Det her gælder stadig, folkens - Tænk jer om, hold hygiejne, bryd smittekæderne og vis hensyn #dkpol #dkmedier #covid19 https://t.co/VkZJbk7jcn
# Hashtags Used:['dkpol', 'dkmedier']
# Date:2021-08-18 13:13:24
#
# Tweet 3:
# Username:lykkefisker
# Description:Nysgerrig 🕵️‍♀️
# Location:Denmark
# Following Count:1028
# Follower Count:681
# Total Tweets:8378
# Retweet Count:0
# Tweet Text:@IgumRasmussen Hvilken fejl har de så begået i Israel? #dkmedier #covid19dk
# Hashtags Used:['dkmedier', 'covid19dk']
# Date:2021-08-17 08:00:56
#
# Tweet 4:
# Username:KlausKblog
# Description:Klaus K, journalist & sangskriver i Danser med Drenge. Skriver om frihed, livsstil, forbud & tvang: https://t.co/yLL8XKHHDv
# Location:København
# Following Count:511
# Follower Count:2478
# Total Tweets:33358
# Retweet Count:1
# Tweet Text:@SSI_dk @SSTSundhed @SSTbrostrom @Heunicke @stinuslindgreen er der en fra officielt hold, der kan forklare betydningen af dette svar fra SSI?
#
# #dkpol #dkmedier #COVID19dk https://t.co/aw6VLQVQum
# Hashtags Used:[]
# Date:2021-08-14 08:16:35
#
# Tweet 5:
# Username:Leoninho
# Description:The YEARBOOK XI.
#
# https://t.co/CM6xcKmTWG
# Location:København
# Following Count:405
# Follower Count:172
# Total Tweets:4396
# Retweet Count:1
# Tweet Text:@SSI_dk @SSTSundhed @SSTbrostrom @Heunicke @stinuslindgreen er der en fra officielt hold, der kan forklare betydningen af dette svar fra SSI?
#
# #dkpol #dkmedier #COVID19dk https://t.co/aw6VLQVQum
# Hashtags Used:['dkpol', 'dkmedier', 'COVID19dk']
# Date:2021-08-14 08:11:03
#
# Tweet 6:
# Username:bettinaskou
# Description:#dkpol
# Location:Danmark
# Following Count:1330
# Follower Count:340
# Total Tweets:45075
# Retweet Count:5
# Tweet Text:Frygt er et politisk redskab. Prof. Richard Werner fortæller på 2min om central bankernes planer. Spoiler alert: social credit
# #dkpol #dkmedier #coronadk #covid19dk #dkbiz https://t.co/YUSUavLsGp
# Hashtags Used:[]
# Date:2021-08-14 07:48:50
#
# Tweet 7:
# Username:DkpKiel
# Description:
# Location:Kiel, Schleswig-Holstein
# Following Count:589
# Follower Count:418
# Total Tweets:1641
# Retweet Count:5
# Tweet Text:Arbejderen mener: Det sociale massemord finder sted hver dag. Aller hæsligst fremstår kapitalismens ansigt når vi hæver os op og kigger på fordelingen af elendigheden globalt.
# https://t.co/vAUOG3DExD
# #dkpol #dkmedier #Covid19dk #ulighed
# Hashtags Used:[]
# Date:2021-08-14 06:09:04
#
# Tweet 8:
# Username:Smitty04491966
# Description:Bor i det salte blæsende udkants Danmark 🌊 Shaman af Gaia's nåde 💓 Mediterer 🧘‍♀️Veganer 🍇
# Location:
# Following Count:180
# Follower Count:101
# Total Tweets:9648
# Retweet Count:5
# Tweet Text:Arbejderen mener: Det sociale massemord finder sted hver dag. Aller hæsligst fremstår kapitalismens ansigt når vi hæver os op og kigger på fordelingen af elendigheden globalt.
# https://t.co/vAUOG3DExD
# #dkpol #dkmedier #Covid19dk #ulighed
# Hashtags Used:[]
# Date:2021-08-13 12:19:54
#
# Tweet 9:
# Username:bjarkhamarmusic
# Description:Liberal socialist. Retwitter of good opinions i... I think😅 vaccinated!! #allnarcsarebastrads
# Location:Aalborg, Danmark
# Following Count:534
# Follower Count:174
# Total Tweets:13606
# Retweet Count:5
# Tweet Text:Arbejderen mener: Det sociale massemord finder sted hver dag. Aller hæsligst fremstår kapitalismens ansigt når vi hæver os op og kigger på fordelingen af elendigheden globalt.
# https://t.co/vAUOG3DExD
# #dkpol #dkmedier #Covid19dk #ulighed
# Hashtags Used:[]
# Date:2021-08-13 11:20:54
#
# Tweet 10:
# Username:kommunister
# Description:Kæmper for et socialistisk velfærdssamfund med lige rettigheder til alle og et aktivt deltagerdemokrati. Udgiver dagbladet @Arbejderen
# Location:Ryesgade 3 F, 2200 København N
# Following Count:1047
# Follower Count:590
# Total Tweets:1788
# Retweet Count:5
# Tweet Text:Arbejderen mener: Det sociale massemord finder sted hver dag. Aller hæsligst fremstår kapitalismens ansigt når vi hæver os op og kigger på fordelingen af elendigheden globalt.
# https://t.co/vAUOG3DExD
# #dkpol #dkmedier #Covid19dk #ulighed
# Hashtags Used:[]
# Date:2021-08-13 11:16:48
#
# Tweet 11:
# Username:anders1984
# Description:Ansvarshavende redaktør på @arbejderen, landsledelsesmedlem hos @kommunister, gift og far til 3. Fang mig på as@arbejderen.dk
# Location:København, Hovedstaden
# Following Count:845
# Follower Count:457
# Total Tweets:4570
# Retweet Count:5
# Tweet Text:Arbejderen mener: Det sociale massemord finder sted hver dag. Aller hæsligst fremstår kapitalismens ansigt når vi hæver os op og kigger på fordelingen af elendigheden globalt.
# https://t.co/vAUOG3DExD
# #dkpol #dkmedier #Covid19dk #ulighed
# Hashtags Used:[]
# Date:2021-08-13 11:16:45
#
# Tweet 12:
# Username:Arbejderen
# Description:Det kæmpende Danmarks digitale dagblad.
# Mest om #arbejde, #klima og #dkpol.
# Henvendelser sker til redaktion@arbejderen.dk.
# Location:Copenhagen
# Following Count:1021
# Follower Count:2830
# Total Tweets:4581
# Retweet Count:5
# Tweet Text:Arbejderen mener: Det sociale massemord finder sted hver dag. Aller hæsligst fremstår kapitalismens ansigt når vi hæver os op og kigger på fordelingen af elendigheden globalt.
# https://t.co/vAUOG3DExD
# #dkpol #dkmedier #Covid19dk #ulighed
# Hashtags Used:['dkpol', 'dkmedier', 'Covid19dk', 'ulighed']
# Date:2021-08-13 11:16:31
#
# Tweet 13:
# Username:nbm_1981
# Description:IT Automation Consultant (MCAAA/MCSA/MCP). Likes logic. Father of 3. Against covid restrictions since June 2020. Private profile.
# Location:København, Danmark
# Following Count:613
# Follower Count:623
# Total Tweets:12454
# Retweet Count:5
# Tweet Text:Frygt er et politisk redskab. Prof. Richard Werner fortæller på 2min om central bankernes planer. Spoiler alert: social credit
# #dkpol #dkmedier #coronadk #covid19dk #dkbiz https://t.co/YUSUavLsGp
# Hashtags Used:['dkpol', 'dkmedier', 'coronadk', 'covid19dk', 'dkbiz']
# Date:2021-08-13 08:11:14
#
# Tweet 14:
# Username:PopeyeKamper
# Description:Vocalist/Adviseur - Geïnteresseerd in: politiek, sport, zingen en is ervaringsdeskundige bij non-profit lotgenotenorganisatie Nederland Heelt.
# Location:
# Following Count:691
# Follower Count:613
# Total Tweets:81561
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-12 16:19:54
#
# Tweet 15:
# Username:VeritasTB2
# Description:#NoMoreWars, lies, imperialism & bad science #FreeAssange
# Life is short, so I block idiots and trolls.
# Likes, follows and retweets do not equal endorsement.
# Location:Nordic
# Following Count:1601
# Follower Count:933
# Total Tweets:53668
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-12 13:37:30
#
# Tweet 16:
# Username:KWS99
# Description:In to #education, #antitotalitarism, #truthsearch, #christianity, #confessional_lutheranism,
# Location:Denmark
# Following Count:514
# Follower Count:171
# Total Tweets:5213
# Retweet Count:0
# Tweet Text:Israelsk Covid19-supermedicin, der behandler 90% af indlagte godt nok til at de kan forlade hospitalet.
# @LMSTdk @SSTSundhed @SSTbrostrom @SSI_dk @DKsundhed @folketinget #dkmedier #COVID19dk #Covid_19 #CovidVaccine #nyheder @kristeligt @berlingske @btdk @ebbreaking @DRBreaking https://t.co/HakVzGlTpi
# Hashtags Used:['dkmedier', 'COVID19dk', 'Covid_19', 'CovidVaccine', 'nyheder']
# Date:2021-08-12 13:17:44
#
# Tweet 17:
# Username:DonaldMacintyr1
# Description:
# Location:
# Following Count:504
# Follower Count:105
# Total Tweets:517
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-12 11:51:58
#
# Tweet 18:
# Username:FaktaHoldninger
# Description:Lader dig ikke ha’ din yndlingsløgn i fred 😉 ..... Vi kan ha’ forskellige holdninger, men vi kan ikke ha’ forskellige fakta 🇩🇰
# Location:
# Following Count:706
# Follower Count:191
# Total Tweets:7075
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-12 10:57:09
#
# Tweet 19:
# Username:hulledulle
# Description:
# Location:DK
# Following Count:1414
# Follower Count:320
# Total Tweets:23695
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-12 10:37:59
#
# Tweet 20:
# Username:CFVby
# Description:
# Location:
# Following Count:339
# Follower Count:83
# Total Tweets:750
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-12 06:55:31
#
# Tweet 21:
# Username:LoneWieberg
# Description:Glad skør og levende
# Location:
# Following Count:443
# Follower Count:252
# Total Tweets:8938
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-12 05:56:14
#
# Tweet 22:
# Username:RhHofs
# Description:Selvstændig, Medlem af Foreningen Rimelig Skat, går ind for respekt og anstændighed, ret til egne penge og ejendom og et samfund der er motiveret og i balance.
# Location:
# Following Count:294
# Follower Count:331
# Total Tweets:32099
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-12 05:28:21
#
# Tweet 23:
# Username:AnMeVase
# Description:My values are health, honesty, politics, mathematics, logic, philosophy, western culture, spirituel world,  life!
# Location:
# Following Count:150
# Follower Count:1001
# Total Tweets:27056
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-12 05:26:45
#
# Tweet 24:
# Username:nick_justa
# Description:CarnSasFitDiveSkyBuletsHiiT.
# Optimum.Insulin related diseases. Dont follow me. In case of fear, dont panic - ORGANISE !
# Location:Flying rock, named Earth
# Following Count:70
# Follower Count:66
# Total Tweets:4001
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-12 01:16:21
#
# Tweet 25:
# Username:jo_bt66
# Description:Psychological Warfare Subversion & Control of Western Society:
# https://t.co/hEh5cSf7pP
# Location:
# Following Count:790
# Follower Count:392
# Total Tweets:7511
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-11 21:18:57
#
# Tweet 26:
# Username:StineLacoul
# Description:Kvinde født i den Frie Verden.
# Kæmpe modstander af #Transhumanism og #CriticalRaceTheory
# Malo periculosam, libertatem quam quietam servitutem
# Location:Danmark
# Following Count:587
# Follower Count:262
# Total Tweets:7240
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-11 20:39:01
#
# Tweet 27:
# Username:kassemanden
# Description:Eksperimenterer i gode kasser | Upload dine investeringer med #csgoinvest og få altid et RT | Følg for at holde dig opdateret
# Location:Steam og Excel
# Following Count:442
# Follower Count:2159
# Total Tweets:10284
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-11 19:31:40
#
# Tweet 28:
# Username:SteffenSrensen5
# Description:
# Location:
# Following Count:844
# Follower Count:620
# Total Tweets:4335
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-11 18:58:12
#
# Tweet 29:
# Username:martinthage
# Description:44years, married, 3 kids, +20years prof. sales experience
# Location:Denmark
# Following Count:585
# Follower Count:93
# Total Tweets:3037
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-11 18:51:27
#
# Tweet 30:
# Username:KlausKblog
# Description:Klaus K, journalist & sangskriver i Danser med Drenge. Skriver om frihed, livsstil, forbud & tvang: https://t.co/yLL8XKHHDv
# Location:København
# Following Count:511
# Follower Count:2478
# Total Tweets:33358
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-11 18:48:21
#
# Tweet 31:
# Username:HettingClaus
# Description:"Three things remain not long hidden: The Sun, the Moon, and the Truth."
# Journalist, tech expert, engineer, aerospace grad.
# Location:Denmark
# Following Count:2254
# Follower Count:2720
# Total Tweets:15786
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:[]
# Date:2021-08-11 17:59:14
#
# Tweet 32:
# Username:nbm_1981
# Description:IT Automation Consultant (MCAAA/MCSA/MCP). Likes logic. Father of 3. Against covid restrictions since June 2020. Private profile.
# Location:København, Danmark
# Following Count:613
# Follower Count:623
# Total Tweets:12454
# Retweet Count:28
# Tweet Text:Israels massevaccination:
# 25% stigning i hjertestop og hjerteanfald i alderen 16-29.
# 86.6% stigning i hjerteanfald i alderen 20-29.
# #dkpol #dkmedier #coronadk #covid19dk #sundpol #dksund @folketinget https://t.co/6ndX3j5dIs
# Hashtags Used:['dkpol', 'dkmedier', 'coronadk', 'covid19dk', 'sundpol', 'dksund']
# Date:2021-08-11 17:50:59
# Scraping has completed!

# %% [markdown]
# ### Combining dataframes

# %%
df1=pd.read_csv('df1.csv')
df2=pd.read_csv('df2.csv')
df3=pd.read_csv('df3.csv')

obs = [df1, df2, df3]

data_set = pd.concat(obs)
data_set = data_set.reset_index(drop = True)
data_set
# Out:
#      Unnamed: 0         username  \
# 0             0  viralvideovlogs
# 1             1      LoneWieberg
# 2             2    FreeObserver3
# 3             3   stefanhandberg
# 4             4    larschristens
# ..          ...              ...
# 560          27  SteffenSrensen5
# 561          28      martinthage
# 562          29       KlausKblog
# 563          30     HettingClaus
# 564          31         nbm_1981
#
#                                            description            location  \
# 0    news news news and trends\n\nhttps://t.co/2ScZ...               കേരളം
# 1                                 Glad skør og levende                 NaN
# 2                                    Independent media                 NaN
# 3                 Selvstændig, kritisk samfundsrevser.              Aarhus
# 4    Deltagerdemokrat. Går op i politik, historie, ...                 NaN
# ..                                                 ...                 ...
# 560                                                NaN                 NaN
# 561  44years, married, 3 kids, +20years prof. sales...             Denmark
# 562  Klaus K, journalist & sangskriver i Danser med...           København
# 563  "Three things remain not long hidden: The Sun,...             Denmark
# 564  IT Automation Consultant (MCAAA/MCSA/MCP). Lik...  København, Danmark
#
#      following  followers  totaltweets  retweetcount  \
# 0         4658       7325       853451             7
# 1          443        252         8938             7
# 2           37        310          329            69
# 3          302        164         2134            69
# 4          190        318         3608             4
# ..         ...        ...          ...           ...
# 560        844        620         4335            28
# 561        585         93         3037            28
# 562        511       2478        33358            28
# 563       2254       2720        15786            28
# 564        613        623        12454            28
#
#                                                   text  \
# 0    1/n. Politiken har i dag et nyt eksempel på då...
# 1    1/n. Politiken har i dag et nyt eksempel på då...
# 2    I Israel er 62,6% af befolkningen fuldt vaccin...
# 3    I Israel er 62,6% af befolkningen fuldt vaccin...
# 4    @PaigeZanco @Charlot45249102 @VeritasTB2 @Luff...
# ..                                                 ...
# 560  Israels massevaccination: \n25% stigning i hje...
# 561  Israels massevaccination: \n25% stigning i hje...
# 562  Israels massevaccination: \n25% stigning i hje...
# 563  Israels massevaccination: \n25% stigning i hje...
# 564  Israels massevaccination: \n25% stigning i hje...
#
#                                               hashtags                 date
# 0                                                   []  2021-08-19 05:50:35
# 1                                                   []  2021-08-19 05:50:34
# 2                                                   []  2021-08-19 05:33:40
# 3                                                   []  2021-08-19 05:16:43
# 4                                                   []  2021-08-19 05:11:14
# ..                                                 ...                  ...
# 560                                                 []  2021-08-11 18:58:12
# 561                                                 []  2021-08-11 18:51:27
# 562                                                 []  2021-08-11 18:48:21
# 563                                                 []  2021-08-11 17:59:14
# 564  ['dkpol', 'dkmedier', 'coronadk', 'covid19dk',...  2021-08-11 17:50:59
#
# [565 rows x 11 columns]

# %% [markdown]
# ### Cleaning the DataFrame

# %%
#https://stackoverflow.com/questions/33404752/removing-emojis-from-a-string-in-python

# %%
emoji_pattern = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
         "]+", flags=re.UNICODE)

# %%
#Dropping collumns
data_set1 = data_set.drop(['Unnamed: 0','username', 'description', 'followers', 'following'], axis=1).reset_index(drop = True)

#Creating collumn for hashtags
data_set1['hashtags'] = data_set1['text'].apply(lambda x: re.findall(r'#(\w+)', x))

#Calling text column
tweets = data_set1['text'].values

# %%
import numpy as np
wnl = nltk.WordNetLemmatizer()

def clean_tweet(tweet):
    if type(tweet) == np.float64:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) 
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('[.,*?:]',' ', temp)
    temp = re.sub('\v', ' ', temp)
    temp = re.sub("[\\n]",' ', temp)
    temp = re.sub('1/n',' ', temp)
    temp = re.sub('2/n',' ', temp)
    temp = re.sub('3/n',' ', temp)
    temp = re.sub('4/n',' ', temp)
    temp = re.sub('5/n',' ', temp)
    temp = re.sub('6/n',' ', temp)
    temp = re.sub('7/n',' ', temp)
    temp = re.sub('8/n',' ', temp)
    temp = re.sub('-','', temp) 
    temp = re.sub('%','', temp)  
    temp = emoji_pattern.sub(r'', temp)
    return temp

# %%
clean_data = [clean_tweet(tweets) for tweets in tweets]

c = str(clean_data)

# %%
#Remove danish stopWords
stopWords = set(stopwords.words('danish'))
wordsFiltered = [] #what does wordsFiltered do?

sent_sw_removed = [i for i in nltk.word_tokenize(c.lower()) if i not in stopWords]

sent_sw_removed
# Out:
# ['[',
#  "'",
#  'politiken',
#  'dag',
#  'nyt',
#  'eksempel',
#  'dårlig',
#  'coronajournalistik',
#  'journalisterne',
#  'brugt',
#  'tid',
#  'læse',
#  'artiklen',
#  'skriver',
#  'konstateret',
#  'række',
#  'mangler',
#  "'",
#  ',',
#  "'",
#  'politiken',
#  'dag',
#  'nyt',
#  'eksempel',
#  'dårlig',
#  'coronajournalistik',
#  'journalisterne',
#  'brugt',
#  'tid',
#  'læse',
#  'artiklen',
#  'skriver',
#  'konstateret',
#  'række',
#  'mangler',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'fortæller',
#  'givet',
#  'fald',
#  'alvorligt',
#  'skærpet',
#  'indberetningspligt',
#  'tilkommer',
#  'tilfældige',
#  'censurere',
#  'netop',
#  'dag',
#  '``',
#  'synes',
#  "''",
#  'mulig',
#  'bivirkning',
#  "'",
#  ',',
#  "'corona",
#  'vira',
#  'muterer',
#  'kontinuerligt',
#  'massevaccination',
#  'fremmer',
#  'naturligvis',
#  'selektion',
#  'mutationer',
#  'følsomme',
#  'vacciner',
#  'cape',
#  'cod',
#  '30',
#  'juli',
#  "'",
#  ',',
#  "'",
#  'politiken',
#  'dag',
#  'nyt',
#  'eksempel',
#  'dårlig',
#  'coronajournalistik',
#  'journalisterne',
#  'brugt',
#  'tid',
#  'læse',
#  'artiklen',
#  'skriver',
#  'konstateret',
#  'række',
#  'mangler',
#  "'",
#  ',',
#  "'",
#  'læs',
#  'fakta',
#  'tjekkernes',
#  'misinformation',
#  'specielt',
#  'fokus',
#  'newsguard',
#  '``',
#  'the',
#  'truth',
#  'is',
#  'best',
#  'sought',
#  'through',
#  'the',
#  'marketplace',
#  'of',
#  'ideas',
#  'where',
#  'reason',
#  'and',
#  'evidence',
#  'are',
#  'the',
#  'weapons',
#  'of',
#  'choice',
#  '``',
#  "'",
#  ',',
#  "'",
#  'kan',
#  'se',
#  'liste',
#  'åbenbart',
#  '98',
#  'certificerede',
#  'faktatjekkere',
#  'certificeret',
#  'hvem',
#  'syg',
#  'forretningsmodel',
#  'virkelig',
#  'brug',
#  'oprydning',
#  'stor',
#  'fejekost',
#  "'",
#  ',',
#  "'",
#  'statsfinansieringen',
#  'tjekdet',
#  'finansieret',
#  'facebook',
#  'tredjepartsfaktatjekker',
#  'åbenbart',
#  'honorering',
#  'pr',
#  'artikel',
#  'facebook',
#  'retter',
#  'regeringens',
#  'ønsker',
#  'beskytte',
#  'virksomheden',
#  "'",
#  ',',
#  "'",
#  'punkt',
#  '6',
#  'fortjener',
#  'speciel',
#  'fokus',
#  'allerhøjeste',
#  'grad',
#  'behov',
#  'fakta',
#  'tjek',
#  'såkaldte',
#  'fakta',
#  'tjekkere',
#  'hvorfor',
#  'betaler',
#  'tjekdet',
#  'bevilling',
#  'folketingets',
#  'finansudvalg',
#  "'",
#  ',',
#  "'",
#  'ti',
#  'gode',
#  'råd',
#  'geert',
#  'vanden',
#  'bossche',
#  'hvordan',
#  'skiller',
#  'skidt',
#  'kanel',
#  'informationsoverflow',
#  'bombarderes',
#  "'",
#  ',',
#  "'",
#  'ti',
#  'gode',
#  'råd',
#  'geert',
#  'vanden',
#  'bossche',
#  'hvordan',
#  'skiller',
#  'skidt',
#  'kanel',
#  'informationsoverflow',
#  'bombarderes',
#  "'",
#  ',',
#  "'corona",
#  'vira',
#  'muterer',
#  'kontinuerligt',
#  'massevaccination',
#  'fremmer',
#  'naturligvis',
#  'selektion',
#  'mutationer',
#  'følsomme',
#  'vacciner',
#  'cape',
#  'cod',
#  '30',
#  'juli',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'corona",
#  'vira',
#  'muterer',
#  'kontinuerligt',
#  'massevaccination',
#  'fremmer',
#  'naturligvis',
#  'selektion',
#  'mutationer',
#  'følsomme',
#  'vacciner',
#  'cape',
#  'cod',
#  '30',
#  'juli',
#  "'",
#  ',',
#  "'corona",
#  'vira',
#  'muterer',
#  'kontinuerligt',
#  'massevaccination',
#  'fremmer',
#  'naturligvis',
#  'selektion',
#  'mutationer',
#  'følsomme',
#  'vacciner',
#  'cape',
#  'cod',
#  '30',
#  'juli',
#  "'",
#  ',',
#  "'corona",
#  'vira',
#  'muterer',
#  'kontinuerligt',
#  'massevaccination',
#  'fremmer',
#  'naturligvis',
#  'selektion',
#  'mutationer',
#  'følsomme',
#  'vacciner',
#  'cape',
#  'cod',
#  '30',
#  'juli',
#  "'",
#  ',',
#  "'",
#  'fortæller',
#  'givet',
#  'fald',
#  'alvorligt',
#  'skærpet',
#  'indberetningspligt',
#  'tilkommer',
#  'tilfældige',
#  'censurere',
#  'netop',
#  'dag',
#  '``',
#  'synes',
#  "''",
#  'mulig',
#  'bivirkning',
#  "'",
#  ',',
#  "'corona",
#  'vira',
#  'muterer',
#  'kontinuerligt',
#  'massevaccination',
#  'fremmer',
#  'naturligvis',
#  'selektion',
#  'mutationer',
#  'følsomme',
#  'vacciner',
#  'cape',
#  'cod',
#  '30',
#  'juli',
#  "'",
#  ',',
#  "'corona",
#  'vira',
#  'muterer',
#  'kontinuerligt',
#  'massevaccination',
#  'fremmer',
#  'naturligvis',
#  'selektion',
#  'mutationer',
#  'følsomme',
#  'vacciner',
#  'cape',
#  'cod',
#  '30',
#  'juli',
#  "'",
#  ',',
#  "'corona",
#  'vira',
#  'muterer',
#  'kontinuerligt',
#  'massevaccination',
#  'fremmer',
#  'naturligvis',
#  'selektion',
#  'mutationer',
#  'følsomme',
#  'vacciner',
#  'cape',
#  'cod',
#  '30',
#  'juli',
#  "'",
#  ',',
#  "'corona",
#  'vira',
#  'muterer',
#  'kontinuerligt',
#  'massevaccination',
#  'fremmer',
#  'naturligvis',
#  'selektion',
#  'mutationer',
#  'følsomme',
#  'vacciner',
#  'cape',
#  'cod',
#  '30',
#  'juli',
#  "'",
#  ',',
#  "'",
#  'politiken',
#  'dag',
#  'nyt',
#  'eksempel',
#  'dårlig',
#  'coronajournalistik',
#  'journalisterne',
#  'brugt',
#  'tid',
#  'læse',
#  'artiklen',
#  'skriver',
#  'konstateret',
#  'række',
#  'mangler',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'politiken',
#  'dag',
#  'nyt',
#  'eksempel',
#  'dårlig',
#  'coronajournalistik',
#  'journalisterne',
#  'brugt',
#  'tid',
#  'læse',
#  'artiklen',
#  'skriver',
#  'konstateret',
#  'række',
#  'mangler',
#  "'",
#  ',',
#  "'myocarditis",
#  'pericarditis',
#  'vaccination',
#  'covid19',
#  '5',
#  '7',
#  'indlæggelser',
#  'pr',
#  '10',
#  '000',
#  'vaccinerede',
#  'myocarditis',
#  'overvægt',
#  'yngre',
#  'mænd',
#  'indlæggelser',
#  'underestimerer',
#  'reelle',
#  'antal',
#  "'",
#  ',',
#  "'",
#  'politiken',
#  'dag',
#  'nyt',
#  'eksempel',
#  'dårlig',
#  'coronajournalistik',
#  'journalisterne',
#  'brugt',
#  'tid',
#  'læse',
#  'artiklen',
#  'skriver',
#  'konstateret',
#  'række',
#  'mangler',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'f',
#  'eks',
#  'sammenlignet',
#  'nedenstående',
#  'datagrundlaget',
#  'omstændigheder',
#  'så',
#  'spinkelt',
#  'basis',
#  'konkludere',
#  'helst',
#  "'",
#  ',',
#  "'",
#  'konstruerede',
#  'resultat',
#  'sammenligner',
#  'så',
#  'bl',
#  'a',
#  'vaers',
#  'data',
#  'uden',
#  'korrektion',
#  'underestimering',
#  'myocarditis',
#  'mindste',
#  'kan',
#  'glæde',
#  'igennem',
#  'peer',
#  'review',
#  "'",
#  ',',
#  "'",
#  'antallet',
#  'myocarditis',
#  'tilfælde',
#  'materialet',
#  'yderst',
#  'sparsom',
#  'korrektion',
#  'foretages',
#  'antaget',
#  'underestimering',
#  'covid19',
#  'uigennemskuelig',
#  "'",
#  ',',
#  "'",
#  'politiken',
#  'dag',
#  'nyt',
#  'eksempel',
#  'dårlig',
#  'coronajournalistik',
#  'journalisterne',
#  'brugt',
#  'tid',
#  'læse',
#  'artiklen',
#  'skriver',
#  'konstateret',
#  'række',
#  'mangler',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'breaking",
#  'usa',
#  'tilbyder',
#  '3',
#  'stik',
#  'boostershots',
#  'covid19vaccinerede',
#  '8',
#  'måneder',
#  '2',
#  'stik',
#  'starter',
#  'efteråret',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'skærer',
#  '&',
#  'lt',
#  ';',
#  '12',
#  'årige',
#  'væk',
#  'nok',
#  'indlagt',
#  'svær',
#  'kritisk',
#  'sygdom',
#  'så',
#  'vaccinationsprocenten',
#  '78',
#  'udgangspunkt',
#  'effekt',
#  'ca',
#  '19',
#  'absolutte',
#  'points',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'israel',
#  '62',
#  '6',
#  'befolkningen',
#  'fuldt',
#  'vaccineret',
#  '15',
#  'august',
#  '2021',
#  '59',
#  'indlagte',
#  '``',
#  'severe',
#  'or',
#  'critical',
#  'covid19',
#  "''",
#  'fuldt',
#  'vaccineret',
#  'vaccinerne',
#  'tilsyneladende',
#  'ingen',
#  'effekt',
#  "'",
#  ',',
#  "'",
#  'ved',
#  'naturligvis',
#  'godt',
#  'blot',
#  'endnu',
#  'understregning',
#  'coronapas',
#  'meningsløse',
#  'oveni',
#  ...]

# %%
from collections import Counter

Counter(sent_sw_removed).most_common()
# Out:
# [("'", 863),
#  (',', 564),
#  ('vaccinerne', 107),
#  ('``', 101),
#  ("''", 95),
#  ('vaccineret', 92),
#  ('fuldt', 90),
#  ('covid19', 85),
#  ('så', 79),
#  ('6', 78),
#  ('ingen', 71),
#  ('vaccinerede', 70),
#  ('vaccination', 69),
#  ('før', 57),
#  ('systematisk', 56),
#  ('undersøgelse', 56),
#  ('effekt', 54),
#  ('viden', 52),
#  ('indlæggelser', 50),
#  ('myndigheder', 50),
#  ('udført', 49),
#  ('befolkningen', 47),
#  ('15', 47),
#  ('vira', 47),
#  ('israel', 46),
#  ('indlagte', 46),
#  ('regulatoriske', 46),
#  ('trods', 46),
#  ('62', 45),
#  ('august', 45),
#  ('2021', 45),
#  ('59', 45),
#  ('severe', 45),
#  ('or', 45),
#  ('critical', 45),
#  ('tilsyneladende', 45),
#  ("'det", 45),
#  ('skandale', 45),
#  ('koagulationssystemsaktivering', 45),
#  ('vaccinegodkendelserne', 45),
#  ('godkendt', 45),
#  ('kan', 44),
#  ('dage', 43),
#  ('se', 42),
#  ('etablerede', 42),
#  ('artikel', 37),
#  ('stigning', 36),
#  ('hjerteanfald', 36),
#  ('alderen', 36),
#  ('lige', 35),
#  ('viser', 34),
#  ('vist', 33),
#  ('godt', 32),
#  ('infektion', 32),
#  ('første', 32),
#  ('længe', 32),
#  ('virker', 32),
#  ('dropin', 32),
#  ('tjekdet', 31),
#  ('pr', 31),
#  ('videnskabelige', 31),
#  ('opfattelsen', 31),
#  ('breakthroughinfektion', 31),
#  ('udskiller', 31),
#  ('uvaccinerede', 31),
#  ('antal', 30),
#  ('tid', 28),
#  ('artiklen', 28),
#  ('10', 28),
#  ('virus', 28),
#  ('massevaccination', 27),
#  ('vacciner', 27),
#  ('myocarditis', 27),
#  ('videnskabelig', 27),
#  ('evidens', 27),
#  ('5', 26),
#  ('helt', 26),
#  ("'myocarditis", 25),
#  ('pericarditis', 25),
#  ('7', 25),
#  ('000', 25),
#  ('overvægt', 25),
#  ('yngre', 25),
#  ('mænd', 25),
#  ('underestimerer', 25),
#  ('reelle', 25),
#  ('muterer', 24),
#  ('kontinuerligt', 24),
#  ('fakta', 24),
#  ('stod', 24),
#  ('uden', 23),
#  ('kritisk', 22),
#  ('faktisk', 22),
#  ('fremmer', 21),
#  ('selektion', 21),
#  ('hvorfor', 21),
#  ("'nyttig", 21),
#  ('sygehustestning', 21),
#  ('troede', 21),
#  ('slemt', 21),
#  ('teststrategien', 21),
#  ('fuldkommen', 21),
#  ('irrationel', 21),
#  ('fremgår', 21),
#  ('pga', 21),
#  ("'den", 21),
#  ('presses', 21),
#  ('kritikløse', 21),
#  ('kolportering', 21),
#  ('coronainfo', 21),
#  ('medfører', 21),
#  ('erkendelsen', 21),
#  ('journalistik', 21),
#  ('eksisterer', 21),
#  ('presse', 21),
#  ('frigør', 21),
#  ('masse', 21),
#  ('perfekt', 21),
#  ('sundhedsmyndigheder', 21),
#  ('delta', 21),
#  ('ace2', 20),
#  ('folketingets', 19),
#  ('25', 19),
#  ('1', 19),
#  ('naturligvis', 18),
#  ('hvordan', 18),
#  ('a', 18),
#  ('år', 18),
#  ('virkeligheden', 18),
#  ('coronakrisen', 18),
#  ("'israels", 18),
#  ('hjertestop', 18),
#  ('1629', 18),
#  ('86', 18),
#  ('2029', 18),
#  ('dag', 17),
#  ('brug', 17),
#  ('gode', 17),
#  ('bl', 17),
#  ('ved', 17),
#  ('ssi', 17),
#  ('ti', 16),
#  ('råd', 16),
#  ('geert', 16),
#  ('vanden', 16),
#  ('bossche', 16),
#  ('skiller', 16),
#  ('skidt', 16),
#  ('kanel', 16),
#  ('informationsoverflow', 16),
#  ('bombarderes', 16),
#  ('f', 16),
#  ('eks', 16),
#  ('3', 16),
#  ('siger', 16),
#  ('indlæg', 16),
#  ("'få", 16),
#  ('tidsbestilling', 16),
#  ('918', 16),
#  ('vaccinationscentrene', 16),
#  ('region', 16),
#  ('hovedstaden', 16),
#  ('916', 16),
#  ('åbningstider', 16),
#  ('dit', 16),
#  ('lokale', 16),
#  ('vaccinecenter', 16),
#  ('fokus', 15),
#  ('hvem', 15),
#  ('2', 15),
#  ('overalt', 15),
#  ('verden', 15),
#  ('erkendes', 15),
#  ('flokimmunitet', 15),
#  ('uopnåelig', 15),
#  ('nået', 15),
#  ('varianten', 15),
#  ('skyldes', 15),
#  ('klart', 14),
#  ('bør', 14),
#  ('baseline', 14),
#  ('+1', 14),
#  ('+2', 14),
#  ('+3', 14),
#  ('+5', 14),
#  ('+7', 14),
#  ('+10', 14),
#  ('+14', 14),
#  ('+21', 14),
#  ('the', 13),
#  ('igennem', 13),
#  ('én', 13),
#  ('betyder', 13),
#  ('vigtigt', 13),
#  ('blevet', 13),
#  ('gjort', 13),
#  ('nedlukninger', 13),
#  ('ansigtsmasker', 13),
#  ('beslutningstagerne', 13),
#  ('åbenbart', 12),
#  ('facebook', 12),
#  ('meningsløse', 12),
#  ('ufølsomme', 12),
#  ('varianter', 12),
#  ('gøres', 12),
#  ('syndebukke', 12),
#  ('ansvarlige', 12),
#  ('inkompetente', 12),
#  ('regeringer', 12),
#  ("'alle", 12),
#  ('opmærksom', 12),
#  ('who', 12),
#  ('levende', 12),
#  ('testene', 12),
#  ('ubrugelige', 12),
#  ('massetestning', 12),
#  ('fejler', 12),
#  ('grad', 11),
#  ('coronavirus', 11),
#  ('mere', 11),
#  ('laboratorium', 11),
#  ('wuhan', 11),
#  ('hurtig', 11),
#  ('ddimer', 11),
#  ('profil', 11),
#  ('betinget', 11),
#  ('godkendte', 11),
#  ('regeringen', 11),
#  ('lytte', 11),
#  ('fremragende', 11),
#  ('læs', 10),
#  ('punkt', 10),
#  ('fortjener', 10),
#  ('speciel', 10),
#  ('allerhøjeste', 10),
#  ('behov', 10),
#  ('tjek', 10),
#  ('såkaldte', 10),
#  ('tjekkere', 10),
#  ('betaler', 10),
#  ('bevilling', 10),
#  ('finansudvalg', 10),
#  ('coronapas', 10),
#  ('beslutning', 10),
#  ('snart', 10),
#  ('national', 10),
#  ('biosafety', 10),
#  ('laboratory', 10),
#  ('bsl4', 10),
#  ('klassificeret', 10),
#  ('arbejder', 10),
#  ('aerosol', 10),
#  ('overførte', 10),
#  ('mikroorganismer', 10),
#  ('forstået', 10),
#  ('indtil', 10),
#  ('nylig', 10),
#  ('tweet', 10),
#  ('taler', 10),
#  ('cdc', 10),
#  ('skriver', 9),
#  ('fortæller', 9),
#  ("'corona", 9),
#  ('mutationer', 9),
#  ('følsomme', 9),
#  ('cape', 9),
#  ('cod', 9),
#  ('30', 9),
#  ('juli', 9),
#  ('regeringens', 9),
#  ('blot', 9),
#  ('endnu', 9),
#  ('understregning', 9),
#  ('oveni', 9),
#  ('diskriminerende', 9),
#  ('skamplet', 9),
#  ('folkestyret', 9),
#  ('herunder', 9),
#  ('danske', 9),
#  ('20', 9),
#  ('faktatjekker', 9),
#  ('nyuddannede', 9),
#  ('journalister', 9),
#  ('undtagelse', 9),
#  ('bachelor', 9),
#  ('bachelorstuderende', 9),
#  ('konstruktionen', 9),
#  ('dybt', 9),
#  ('useriøs', 9),
#  ('surprise', 9),
#  ('sarscov2', 9),
#  ('ekspressionen', 9),
#  ('forskellige', 9),
#  ('organer', 9),
#  ('fik', 9),
#  ('videoen', 9),
#  ('advarsel', 9),
#  ('misleading', 9),
#  ('fordi', 9),
#  ('health', 9),
#  ('officials', 9),
#  ('consider', 9),
#  ('vaccines', 9),
#  ('safe', 9),
#  ('most', 9),
#  ('people', 9),
#  ('efficacy', 9),
#  ('safety', 9),
#  ('magthavere', 9),
#  ('definere', 9),
#  ('få', 9),
#  ('mundbind', 9),
#  ('transport', 9),
#  ('brugt', 8),
#  ('mangler', 8),
#  ('of', 8),
#  ('stor', 8),
#  ('bivirkninger', 8),
#  ("'ansigtsmasker", 8),
#  ('bekendt', 8),
#  ('dokumenterbar', 8),
#  ('smittespredning', 8),
#  ('heller', 8),
#  ('malaysia', 8),
#  ('8/1/20', 8),
#  ('01', 8),
#  ('08', 8),
#  ('2020', 8),
#  ("'er", 8),
#  ('politikere', 8),
#  ('mdrs', 8),
#  ('latenstid', 8),
#  ('begynde', 8),
#  ('forholde', 8),
#  ('sproteinet', 8),
#  ('100', 8),
#  ('no', 8),
#  ('opsummering', 8),
#  ('kendte', 8),
#  ('nyrerne', 8),
#  ('organsystemerne', 8),
#  ('høj', 8),
#  ('ekspression', 8),
#  ('sociale', 8),
#  ("'fra", 8),
#  ('lørdag', 8),
#  ('slut', 8),
#  ('kollektiv', 8),
#  ('kæmpe', 8),
#  ('tak', 8),
#  ('transportører', 8),
#  ('medarbejdere', 8),
#  ('borgere', 8),
#  ('gennem', 8),
#  ('hele', 8),
#  ('holdt', 8),
#  ('politiken', 7),
#  ('nyt', 7),
#  ('eksempel', 7),
#  ('dårlig', 7),
#  ('coronajournalistik', 7),
#  ('journalisterne', 7),
#  ('læse', 7),
#  ('konstateret', 7),
#  ('række', 7),
#  ('ønsker', 7),
#  ('alligevel', 7),
#  ('overvejende', 7),
#  ('sikkert', 7),
#  ('booster', 7),
#  ('opformeres', 7),
#  ('påvisning', 7),
#  ('går', 7),
#  ('fordelingen', 7),
#  ('hver', 7),
#  ('mener', 7),
#  ('netop', 6),
#  ('liste', 6),
#  ('98', 6),
#  ('certificerede', 6),
#  ('faktatjekkere', 6),
#  ('certificeret', 6),
#  ('syg', 6),
#  ('forretningsmodel', 6),
#  ('virkelig', 6),
#  ('oprydning', 6),
#  ('fejekost', 6),
#  ('statsfinansieringen', 6),
#  ('finansieret', 6),
#  ('tredjepartsfaktatjekker', 6),
#  ('honorering', 6),
#  ('retter', 6),
#  ('beskytte', 6),
#  ('virksomheden', 6),
#  ('allerede', 6),
#  ('delta+', 6),
#  ('andet', 6),
#  ('steder', 6),
#  ('mutationerne', 6),
#  ('fortsætter', 6),
#  ('fastholder', 6),
#  ('børnene', 6),
#  ('vaccineres', 6),
#  ('gives', 6),
#  ('del', 6),
#  ("'vira", 6),
#  ('energiproduktion', 6),
#  ('pakke', 6),
#  ('genetisk', 6),
#  ('materiale', 6),
#  ('kun', 6),
#  ('celler', 6),
#  ('isolering', 6),
#  ('sikre', 6),
#  ('/', 6),
#  ("'her", 6),
#  ('offentlige', 6),
#  ('vaccine', 6),
#  ('bare', 6),
#  ('jeres', 6),
#  ("'arbejderen", 6),
#  ('massemord', 6),
#  ('finder', 6),
#  ('sted', 6),
#  ('aller', 6),
#  ('hæsligst', 6),
#  ('fremstår', 6),
#  ('kapitalismens', 6),
#  ('ansigt', 6),
#  ('hæver', 6),
#  ('kigger', 6),
#  ('elendigheden', 6),
#  ('globalt', 6),
#  ('alvorligt', 5),
#  ('mulig', 5),
#  ('tilfælde', 5),
#  ('stik', 5),
#  ('nok', 5),
#  ('idé', 5),
#  ('personer', 5),
#  ('ansvaret', 5),
#  ('ansvar', 5),
#  ('måske', 5),
#  ('diameteren', 5),
#  ('pollen', 5),
#  ('luften', 5),
#  ('tre', 5),
#  ('burde', 5),
#  ('restriktioner', 5),
#  ('får', 5),
#  ('bearbejdet', 5),
#  ('referat', 5),
#  ('janci', 5),
#  ('lindsays', 5),
#  ('møde', 5),
#  ('’', 5),
#  ('s', 5),
#  ('advisory', 5),
#  ('committee', 5),
#  ('on', 5),
#  ('immunization', 5),
#  ('practices', 5),
#  ('23', 5),
#  ('04', 5),
#  ('21', 5),
#  ('følgende', 5),
#  ('bruges', 5),
#  ('eksperter', 5),
#  ('modtagelige', 5),
#  ('tilhører', 5),
#  ('virusfamilie', 5),
#  ("'hvis", 5),
#  ("'sarscov2", 5),
#  ('findes', 5),
#  ('pandemi', 5),
#  ('røvrendt', 5),
#  ('egne', 5),
#  ('skattekroner', 5),
#  ('indblik', 5),
#  ("'stærk", 5),
#  ('udmelding', 5),
#  ('givet', 4),
#  ('fald', 4),
#  ('skærpet', 4),
#  ('indberetningspligt', 4),
#  ('tilkommer', 4),
#  ('tilfældige', 4),
#  ('censurere', 4),
#  ('synes', 4),
#  ('bivirkning', 4),
#  ('tjekkernes', 4),
#  ('misinformation', 4),
#  ('specielt', 4),
#  ('newsguard', 4),
#  ('truth', 4),
#  ('is', 4),
#  ('best', 4),
#  ('sought', 4),
#  ('through', 4),
#  ('marketplace', 4),
#  ('ideas', 4),
#  ('where', 4),
#  ('reason', 4),
#  ('and', 4),
#  ('evidence', 4),
#  ('are', 4),
#  ('weapons', 4),
#  ('choice', 4),
#  ('væk', 4),
#  ('handler', 4),
#  ('unge', 4),
#  ('sidder', 4),
#  ('bestyrelsen', 4),
#  ('amatøragtige', 4),
#  ('konstruktion', 4),
#  ('mindst', 4),
#  ('deltaget', 4),
#  ('forarbejdet', 4),
#  ('sidste', 4),
#  ('symptomer', 4),
#  ('selvfølgelig', 4),
#  ("'fjernelse", 4),
#  ('nterminale', 4),
#  ('medvirke', 4),
#  ('reducere', 4),
#  ('risikoen', 4),
#  ('ade', 4),
#  ('fjerner', 4),
#  ('immunologiske', 4),
#  ('reaktion', 4),
#  ('præsentation', 4),
#  ('binding', 4),
#  ('forudsætter', 4),
#  ('gange', 4),
#  ('mindre', 4),
#  ('imellem', 4),
#  ('fint', 4),
#  ('beskæftiger', 4),
#  ('vide', 4),
#  ('endothelceller', 4),
#  ('udtrykker', 4),
#  ('må', 4),
#  ('morgen', 4),
#  ("'sådan", 4),
#  ('forklaret', 4),
#  ('minutter', 4),
#  ('hold', 4),
#  ('måneder', 3),
#  ('&', 3),
#  ('lt', 3),
#  (';', 3),
#  ('12', 3),
#  ('naturlig', 3),
#  ('immunitet', 3),
#  ('rigtig', 3),
#  ('god', 3),
#  ('udviklet', 3),
#  ('gennemtestet', 3),
#  ('millioner', 3),
#  ('lægegerning', 3),
#  ('gribe', 3),
#  ('nødvendigt', 3),
#  ('unødvendigt', 3),
#  ('mulige', 3),
#  ('indberettes', 3),
#  ('lægemiddelstyrelsens', 3),
#  ('hjemmeside', 3),
#  ('corona', 3),
#  ('børn', 3),
#  ('positiv', 3),
#  ('godkendelsesprocessen', 3),
#  ('lægemidler', 3),
#  ('kontrollerer', 3),
#  ('sprotein', 3),
#  ('organspecifik', 3),
#  ('kortlægning', 3),
#  ('interaktion', 3),
#  ('9/n', 3),
#  ('store', 3),
#  ('tusinder', 3),
#  ('smitte', 3),
#  ('undersøgelsen', 3),
#  ('tilstrækkeligt', 3),
#  ('patienter', 3),
#  ('udføres', 3),
#  ('daglig', 3),
#  ('ulejlighed', 3),
#  ('forsøspersonerne', 3),
#  ('grupper', 3),
#  ('dyrene', 3),
#  ('liv', 3),
#  ('andre', 3),
#  ('samme', 3),
#  ('folk', 3),
#  ('smitter', 3),
#  ('høre', 3),
#  ('fuldstændigt', 3),
#  ('thomas', 3),
#  ('liberal', 3),
#  ('alliances', 3),
#  ('partileder', 3),
#  ('alex', 3),
#  ('vanopslagh', 3),
#  ('coronarestriktioner', 3),
#  ('interview', 3),
#  ('stadig', 3),
#  ('politisk', 3),
#  ('sammenlignet', 2),
#  ('korrektion', 2),
#  ('underestimering', 2),
#  ('8', 2),
#  ('sygdom', 2),
#  ('ca', 2),
#  ('lav', 2),
#  ('pcrtests', 2),
#  ('relevante', 2),
#  ('mhp', 2),
#  ('ansatte', 2),
#  ('direkte', 2),
#  ('organisationen', 2),
#  ('gerne', 2),
#  ('arbejde', 2),
#  ('forhåbentlig', 2),
#  ('skrevet', 2),
#  ('formel', 2),
#  ('ansættelseskontrakt', 2),
#  ('1000', 2),
#  ('mængder', 2),
#  ('transporteres', 2),
#  ('luftbåren', 2),
#  ('atmosfæren', 2),
#  ('km', 2),
#  ('sammenhængen', 2),
#  ('små', 2),
#  ('partiklers', 2),
#  ('tilstedeværelse', 2),
#  ('undersøgt', 2),
#  ('korrelation', 2),
#  ('partikelkoncentration', 2),
#  ('evt', 2),
#  ('støvpartikler', 2),
#  ('aerosoler', 2),
#  ('partikler', 2),
#  ('μm', 2),
#  ('afsnit', 2),
#  ('mikrobiologi', 2),
#  ('kurset', 2),
#  ('udmærket', 2),
#  ('underafsnit', 2),
#  ('pcr', 2),
#  ('teknikken', 2),
#  ('smittes', 2),
#  ('epidemien', 2),
#  ('tilbage', 2),
#  ('tro', 2),
#  ('vel', 2),
#  ('forvente', 2),
#  ('sundhedseksperter', 2),
#  ('lukke', 2),
#  ('landet', 2),
#  ('indføre', 2),
#  ('fda', 2),
#  ('advarer', 2),
#  ('sjældne', 2),
#  ('hjertebetændelse', 2),
#  ('tweetet', 2),
#  ('herover', 2),
#  ('label', 2),
#  ('indholdet', 2),
#  ('gøre', 2),
#  ('syge', 2),
#  ('ligesom', 2),
#  ('grund', 2),
#  ('danmark', 2),
#  ('sker', 2),
#  ('tal', 2),
#  ('taliban', 2),
#  ('minkfarm', 2),
#  ("'beder", 2),
#  ('indberette', 2),
#  ('tydeligt', 2),
#  ('opfordrer', 2),
#  ('overgreb', 2),
#  ('tvang', 2),
#  ('vold', 2),
#  ('hjemme', 2),
#  ('medier', 2),
#  ('monstre', 2),
#  ('skabt', 2),
#  ("'jeg", 2),
#  ('fået', 2),
#  ('to', 2),
#  ('dk', 2),
#  ("'en", 2),
#  ('historie', 2),
#  ('virkelige', 2),
#  ("'dansk", 2),
#  ('politik', 2),
#  ('overtaget', 2),
#  ('skadelig', 2),
#  ('biopolitik', 2),
#  ('baseret', 2),
#  ('totalitære', 2),
#  ('tendenser', 2),
#  ('lover', 2),
#  ('dårligt', 2),
#  ('fremtiden', 2),
#  ('aastrup', 2),
#  ('rømer', 2),
#  ('debatindlæg', 2),
#  ('mand', 2),
#  ("'covid19", 2),
#  ('særlig', 2),
#  ('sang', 2),
#  ('indendørs', 2),
#  ('ørnenemodcovid19', 2),
#  ('åren', 2),
#  ("'og", 2),
#  ('cepos', 2),
#  ('vogn', 2),
#  ('bestyrelsesmedlem', 2),
#  ('christian', 2),
#  ('bjørnskov', 2),
#  ('skammeligt', 2),
#  ('situationen', 2),
#  ("'presset", 2),
#  ('stiger', 2),
#  ('rundspørge', 2),
#  ('foretaget', 2),
#  ('hvilke', 2),
#  ('partier', 2),
#  ('sløjfe', 2),
#  ('coronarestriktionerne', 2),
#  ('tsk', 2),
#  ('selvom', 2),
#  ('tænk', 2),
#  ('mål', 2),
#  ('vis', 2),
#  ('gælder', 2),
#  ('officielt', 2),
#  ('forklare', 2),
#  ('betydningen', 2),
#  ('svar', 2),
#  ("'frygt", 2),
#  ('redskab', 2),
#  ('prof', 2),
#  ('richard', 2),
#  ('werner', 2),
#  ('2min', 2),
#  ('central', 2),
#  ('bankernes', 2),
#  ('planer', 2),
#  ('spoiler', 2),
#  ('alert', 2),
#  ('social', 2),
#  ('credit', 2),
#  ('[', 1),
#  ('nedenstående', 1),
#  ('datagrundlaget', 1),
#  ('omstændigheder', 1),
#  ('spinkelt', 1),
#  ('basis', 1),
#  ('konkludere', 1),
#  ('helst', 1),
#  ('konstruerede', 1),
#  ('resultat', 1),
#  ('sammenligner', 1),
#  ('vaers', 1),
#  ('data', 1),
#  ('mindste', 1),
#  ('glæde', 1),
#  ('peer', 1),
#  ('review', 1),
#  ('antallet', 1),
#  ('materialet', 1),
#  ('yderst', 1),
#  ('sparsom', 1),
#  ('foretages', 1),
#  ('antaget', 1),
#  ('uigennemskuelig', 1),
#  ("'breaking", 1),
#  ('usa', 1),
#  ('tilbyder', 1),
#  ('boostershots', 1),
#  ('covid19vaccinerede', 1),
#  ('starter', 1),
#  ('efteråret', 1),
#  ('skærer', 1),
#  ('årige', 1),
#  ('indlagt', 1),
#  ('svær', 1),
#  ('vaccinationsprocenten', 1),
#  ('78', 1),
#  ('udgangspunkt', 1),
#  ('19', 1),
#  ('absolutte', 1),
#  ('points', 1),
#  ("'børn", 1),
#  ('ekstremt', 1),
#  ('sandsynlighed', 1),
#  ('alvorlig', 1),
#  ('død', 1),
#  ('sundhedsmæssig', 1),
#  ('gevinst', 1),
#  ('risiko', 1),
#  ('vaccinebivirkninger', 1),
#  ("'indlagte", 1),
#  ('117', 1),
#  ('heraf', 1),
#  ('intensiv', 1),
#  ('forsøger', 1),
#  ('krampetrækninger', 1),
#  ('holde', 1),
#  ('frugten', 1),
#  ('live', 1),
#  ('sande', 1),
#  ('positive', 1),
#  ('optræder', 1),
#  ('testen', 1),
#  ('sandt', 1),
#  ('b', 1),
#  ('4', 1),
#  ('asymptomatiske', 1),
#  ('ct', 1),
#  ("'carl", 1),
#  ('heneghan', 1),
#  ('tilmed', 1),
#  ('venlighed', 1),
#  ('tillægge', 1),
#  ('flattening', 1),
#  ('curve', 1),
#  ('papskiltet', 1),
#  ('betydning', 1),
#  ('udstrække', 1),
#  ('smittespredningen', 1),
#  ('tods', 1),
#  ('tværtimod', 1),
#  ('kvalificeret', 1),
#  ('analyser', 1),
#  ('problemerne', 1),
#  ('fortsat', 1),
#  ('hovedløst', 1),
#  ('ansvarspådragende', 1),
#  ('“', 1),
#  ('kina', 1),
#  ('gå', 1),
#  ('verdenssundhedsorganisationen', 1),
#  ('forsker', 1),
#  ('yderligere', 1),
#  ('teorien', 1),
#  ('opstod', 1),
#  ('”', 1),
#  ('nej', 1),
#  ('imagine', 1),
#  ('my', 1),
#  ('udåndes', 1),
#  ('indlejret', 1),
#  ('mikrodråber', 1),
#  ('hurtigt', 1),
#  ('tørrer', 1),
#  ('herefter', 1),
#  ('svæver', 1),
#  ('frit', 1),
#  ('bundet', 1),
#  ('diameter', 1),
#  ('1502000', 1),
#  ('større', 1),
#  ('luftbårne', 1),
#  ('submikrone', 1),
#  ('dvs', 1),
#  ('mikrometer', 1),
#  ('=', 1),
#  ('−6', 1),
#  ('m', 1),
#  ('sod', 1),
#  ('smådråber', 1),
#  ('0', 1),
#  ('050', 1),
#  ('14', 1),
#  ('bede', 1),
#  ('udfasning', 1),
#  ('coronapasset', 1),
#  ('støt', 1),
#  ('borgerforslaget', 1),
#  ('ophæv', 1),
#  ('id', 1),
#  ('ft07983', 1),
#  ('eksponeret', 1),
#  ('observeres', 1),
#  ('udvikling', 1),
#  ('modellen', 1),
#  ('undersøges', 1),
#  ('efterfølgende', 1),
#  ('påvises', 1),
#  ('sammenhæng', 1),
#  ('eksposition', 1),
#  ('dyremodel', 1),
#  ('dyrearter', 1),
#  ('vækstmediet', 1),
#  ('indeholder', 1),
#  ('forstøves', 1),
#  ('indånder', 1),
#  ('absurd', 1),
#  ('komisk', 1),
#  ('touch', 1),
#  ('sørgeligt', 1),
#  ('partiernes', 1),
#  ('sundhedsmyndighedernes', 1),
#  ('landsskadelige', 1),
#  ('forløb', 1),
#  ('glemmes', 1),
#  ('hensigten', 1),
#  ('først', 1),
#  ('gennemfører', 1),
#  ('folketingspolitikerne', 1),
#  ('soler', 1),
#  ('fodslæbende', 1),
#  ('genåbning', 1),
#  ('normale', 1),
#  ('mistet', 1),
#  ('enhver', 1),
#  ('form', 1),
#  ('legitimitet', 1),
#  ('gør', 1),
#  ('mon', 1),
#  ('nogen', 1),
#  ('smitteopsporing', 1),
#  ('effektivt', 1),
#  ('transporteret', 1),
#  ('vinden', 1),
#  ('kilometer', 1),
#  ('ja', 1),
#  ('bekymrende', 1),
#  ('producenten', 1),
#  ('udføre', 1),
#  ('toxikologiske', 1),
#  ('kliniske', 1),
#  ('undersøgelser', 1),
#  ('virkning', 1),
#  ('sikkerhed', 1),
#  ('myndigheders', 1),
#  ('acceptabelt', 1),
#  ('kendt', 1),
#  ('væv', 1),
#  ('bemærk', 1),
#  ('luftveje', 1),
#  ('lunger', 1),
#  ('fundet', 1),
#  ('organsystemer', 1),
#  ('18', 1),
#  ('observationer', 1),
#  ('diamond', 1),
#  ('princess', 1),
#  ('vidst', 1),
#  ('udvikler', 1),
#  ('population', 1),
#  ('bestående', 1),
#  ('ældre', 1),
#  ('regering', 1),
#  ('forstå', 1),
#  ('ellers', 1),
#  ('basal', 1),
#  ('immunologi', 1),
#  ('årevis', 1),
#  ('stort', 1),
#  ('set', 1),
#  ('fænomen', 1),
#  ('foregået', 1),
#  ('svinstalde', 1),
#  ('højt', 1),
#  ('antibiotikaforbrug', 1),
#  ("'jamen", 1),
#  ('skruen', 1),
#  ('ende', 1),
#  ('året', 1),
#  ('forudsagt', 1),
#  ('mfs', 1),
#  ('venner', 1),
#  ('østrig', 1),
#  ('styr', 1),
#  ("'vi", 1),
#  ('lærer', 1),
#  ('ergo', 1),
#  ('fuldstændig', 1),
#  ('ligegyldigt', 1),
#  ('afskaffes', 1),
#  ("'skal", 1),
#  ('dækning', 1),
#  ('sverige', 1),
#  ('svenskere', 1),
#  ('døde', 1),
#  ('voldsom', 1),
#  ('overdødelighed', 1),
#  ('præcis', 1),
#  ('dagligt', 1),
#  ('måde', 1),
#  ('vaccinen', 1),
#  ('effektiv', 1),
#  ('sikker', 1),
#  ('retvisende', 1),
#  ...]
