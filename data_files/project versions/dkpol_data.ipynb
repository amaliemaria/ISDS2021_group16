# %%
# Python Script to Extract tweets of a 
# particular Hashtag using Tweepy and Pandas

# import modules
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import datetime
import tweepy
import json
import pandas as pd
import csv
import re #regular expression
from textblob import TextBlob
import string
import preprocessor as p
import os
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\axbae\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\axbae\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df1=pd.read_csv('dkpol0.csv')
df2=pd.read_csv('dkpol1.csv')
df3=pd.read_csv('dkpol2.csv')
df4=pd.read_csv('dkpol3.csv')
df5=pd.read_csv('dkpol4.csv')
df6=pd.read_csv('dkpol5.csv')
df7=pd.read_csv('dkpol6.csv')



obs = [df1, df2, df3, df4, df5, df6, df7]

data_set = pd.concat(obs)
data_set = data_set.reset_index(drop = True)

data_set.to_csv('dkpol_data.csv', encoding = 'utf-8', index= False)
dkpol = pd.read_csv('dkpol_data.csv')

# %%
dkpol
# Out:
#       Unnamed: 0         username  \
# 0              0          KKockii
# 1              1   MargueritteEch
# 2              2        dkpol_net
# 3              3       kristeligt
# 4              4      HermansenBo
# ...          ...              ...
# 1990         280           tbhdkx
# 1991         281        SFpolitik
# 1992         282   KennethNrgaard
# 1993         283     DOppenheuser
# 1994         284  LiselotteWiller
#
#                                             description  \
# 0     Indfødsretnørd.   🇩🇰\nFT-kandidat for @alterna...
# 1     |⚜️Author & Freelance-writer⚜️|L&R~Egmont~Alle...
# 2     https://t.co/RXPQSSsMaN er et website, der min...
# 3     Avisen om livets store spørgsmål. Og især #dkt...
# 4     I work for the Danish State railways.       I ...
# ...                                                 ...
# 1990  Privatlivsnørd og en del af @cryptohagen (#cry...
# 1991                            Socialistisk Folkeparti
# ...
