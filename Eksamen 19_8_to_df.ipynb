# %%
# Python Script to Extract tweets of a 
# particular Hashtag using Tweepy and Pandas

# import modules
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
from collections import defaultdict
import datetime
import tweepy
import json
import pandas as pd
import csv
import re #regular expression
from textblob import TextBlob
import string
import preprocessor as p
import os
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import nltk
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\axbae\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\axbae\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
# function to display data of each tweet
def printtweetdata(n, ith_tweet):
    print()
    print(f"Tweet {n}:")
    print(f"Username:{ith_tweet[0]}")
    print(f"Description:{ith_tweet[1]}")
    print(f"Location:{ith_tweet[2]}")
    print(f"Following Count:{ith_tweet[3]}")
    print(f"Follower Count:{ith_tweet[4]}")
    print(f"Total Tweets:{ith_tweet[5]}")
    print(f"Retweet Count:{ith_tweet[6]}")
    print(f"Tweet Text:{ith_tweet[7]}")
    print(f"Hashtags Used:{ith_tweet[8]}")
    print(f"Date:{ith_tweet[9]}")

# %%
#importer dansk som sprog
#pip install afinn
from afinn import Afinn
afinn = Afinn(language='da')
afinn.score('Hvis ikke det er det mest afskyelige flueknepperi...')
-6.0

#user = api.get_status(id)
  
# fetching the created_at attribute
#created_at = status.created_at 

#today = datetime.date.today()
# Out:
# -6.0

# %%
# function to perform data extraction
def scrape(words, date_since, numtweet):
      
    # Creating DataFrame using pandas
    db = pd.DataFrame(columns=['username', 'description', 'location', 'following',
                               'followers', 'totaltweets', 'retweetcount', 'text', 'hashtags', 'date'])
      
    # We are using .Cursor() to search through twitter for the required tweets.
    # The number of tweets can be restricted using .items(number of tweets)
    tweets = tweepy.Cursor(api.search, q=words, lang="da",
                           since=date_since, tweet_mode='extended').items(numtweet)
     
    # .Cursor() returns an iterable object. Each item in 
    # the iterator has various attributes that you can access to 
    # get information about each tweet
    list_tweets = [tweet for tweet in tweets]
      
    # Counter to maintain Tweet Count
    i = 1  
      
    # we will iterate over each tweet in the list for extracting information about each tweet
    for tweet in list_tweets:
        username = tweet.user.screen_name
        description = tweet.user.description
        location = tweet.user.location
        following = tweet.user.friends_count
        followers = tweet.user.followers_count
        totaltweets = tweet.user.statuses_count
        retweetcount = tweet.retweet_count
        hashtags = tweet.entities['hashtags']
        date = tweet.created_at
          
        # Retweets can be distinguished by a retweeted_status attribute,
        # in case it is an invalid reference, except block will be executed
        try:
            text = tweet.retweeted_status.full_text
        except AttributeError:
            text = tweet.full_text
        hashtext = list()
        for j in range(0, len(hashtags)):
            hashtext.append(hashtags[j]['text'])
          
        # Here we are appending all the extracted information in the DataFrame
        ith_tweet = [username, description, location, following,
                     followers, totaltweets, retweetcount, text, hashtext, date]
        db.loc[len(db)] = ith_tweet
        
          
        # Function call to print tweet data on screen
        printtweetdata(i, ith_tweet)
        i = i+1
    filename = 'dkpol.csv'
      
    # we will save our database as a CSV file.
    db.to_csv(filename)
  
  
if __name__ == '__main__':
      
    # Enter your own credentials obtained 
    # from your developer account
    consumer_key = "HlgemqHuJ83L0NkQbg4rZQLQ1"
    consumer_secret = "iT2MPE5T2n4pGqDlTbFsStnlPyRPgOvk64bEhdRA7ZTE86G60g"
    access_key = "1427158064092876800-MNinx9VxTMhQf07xIutt2upLZvAaPn"
    access_secret = "Utlu32drsCwKj3SnCAYU2qKZ66VNovYBxLxdRu4DeDWrA"
    auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_key, access_secret)
    api = tweepy.API(auth)
      
    # Enter Hashtag and initial date
    print("Enter Twitter HashTag to search for")
    words = input()
    print("Enter Date since The Tweets are required in yyyy-mm--dd")
    date_since = input()
      
    # number of tweets you want to extract in one run
    numtweet = 5000
    scrape(words, date_since, numtweet)
    print('Scraping has completed!')
# Out:
# Enter Twitter HashTag to search for
# dkpol
# Enter Date since The Tweets are required in yyyy-mm--dd
# 2021-08-01
# ---------------------------------------------------------------------------
# TweepError                                Traceback (most recent call last)
# <ipython-input-141-644bc1830d21> in <module>
#      76     # number of tweets you want to extract in one run
#      77     numtweet = 5000
# ---> 78     scrape(words, date_since, numtweet)
#      79     print('Scraping has completed!')
#
# <ipython-input-141-644bc1830d21> in scrape(words, date_since, numtweet)
#      14     # the iterator has various attributes that you can access to
#      15     # get information about each tweet
# ---> 16     list_tweets = [tweet for tweet in tweets]
#      17
#      18     # Counter to maintain Tweet Count
#
# <ipython-input-141-644bc1830d21> in <listcomp>(.0)
#      14     # the iterator has various attributes that you can access to
#      15     # get information about each tweet
# ---> 16     list_tweets = [tweet for tweet in tweets]
#      17
#      18     # Counter to maintain Tweet Count
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in __next__(self)
#      49
#      50     def __next__(self):
# ---> 51         return self.next()
#      52
#      53     def next(self):
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     241         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     242             # Reached end of current page, get the next page...
# --> 243             self.current_page = self.page_iterator.next()
#     244             while len(self.current_page) == 0:
#     245                 self.current_page = self.page_iterator.next()
#
# ~\anaconda3\lib\site-packages\tweepy\cursor.py in next(self)
#     130
#     131         if self.index >= len(self.results) - 1:
# --> 132             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kwargs)
#     133
#     134             if hasattr(self.method, '__self__'):
#
# ~\anaconda3\lib\site-packages\tweepy\binder.py in _call(*args, **kwargs)
#     251                 return method
#     252             else:
# --> 253                 return method.execute()
#     254         finally:
#     255             method.session.close()
#
# ~\anaconda3\lib\site-packages\tweepy\binder.py in execute(self)
#     232                     raise RateLimitError(error_msg, resp)
#     233                 else:
# --> 234                     raise TweepError(error_msg, resp, api_code=api_error_code)
#     235
#     236             # Parse the response payload
#
# TweepError: Twitter error response: status code = 429

# %% [markdown]
# ### Combining dataframes

# %%
df1=pd.read_csv('df1.csv')
df2=pd.read_csv('df2.csv')
df3=pd.read_csv('df3.csv')

obs = [df1, df2, df3]

data_set = pd.concat(obs)
data_set = data_set.reset_index(drop = True)

data_set.to_csv('twitter_data.csv', encoding = 'utf-8', index= False)

data_set
# Out:
#       Unnamed: 0         username  \
# 0              0       SupAyaLaya
# 1              1         Mullarrd
# 2              2         GitteKJP
# 3              3  idamariehansen7
# 4              4       ThomasHeie
# ...          ...              ...
# 1731          26       KlausKblog
# 1732          27     HettingClaus
# 1733          28         nbm_1981
# 1734          29  transceiverfreq
# 1735          30          CirkuzE
#
#                                             description  \
# 0                                                   NaN
# 1     Nearsighted scrap pile, perpetual lefty. Searc...
# 2     Søger viden, nyheder og indsigter til eftertanke.
# 3                                                   NaN
# 4          Fængselsbetjent - FREM'er - Fotograf - FDFer
# ...                                                 ...
# 1731  Klaus K, journalist & sangskriver i Danser med...
# 1732  "Three things remain not long hidden: The Sun,...
# 1733  IT Automation Consultant (MCAAA/MCSA/MCP). Lik...
# 1734  xi=aixi'-(d+ai0+ai1)xi+rxi(fi-Φ ) | Freelance ...
# 1735       Cirkuz Pol-Etik Et samfunds satirisk program
#
#                     location  following  followers  totaltweets  retweetcount  \
# 0                        NaN       1228        521        34115             1
# 1                    Pangaea        515        536        39951            17
# 2                  København        972        947       231239            17
# 3          Nykøbing Sjælland       1292        346        21549            17
# 4         København, Danmark        111        269        21567             0
# ...                      ...        ...        ...          ...           ...
# 1731               København        511       2464        33254            28
# 1732                 Denmark       2249       2717        15616            28
# 1733      København, Danmark        612        624        12430            28
# 1734  Frederiksberg, Denmark        339       1089        44893             0
# 1735                     NaN        179          1           45             0
#
#                                                    text  \
# 0     Beder alle indberette dette tweet, da det tyde...
# 1     Få din vaccination uden tidsbestilling. Der er...
# 2     Få din vaccination uden tidsbestilling. Der er...
# 3     Få din vaccination uden tidsbestilling. Der er...
# 4     Indsatsen i Afghanistan har kostet Danmark 15 ...
# ...                                                 ...
# 1731  Israels massevaccination: \n25% stigning i hje...
# 1732  Israels massevaccination: \n25% stigning i hje...
# 1733  Israels massevaccination: \n25% stigning i hje...
# 1734  @DRNyheder @tv2newsdk @moderna_tx @pfizer Jeg ...
# 1735  Kan man få en klima-vaccine?? Så er @Spolitik ...
#
#                                                hashtags                 date
# 0                                                    []  2021-08-16 23:59:33
# 1                                                    []  2021-08-16 21:14:11
# 2                                                    []  2021-08-16 16:41:45
# 3                                                    []  2021-08-16 16:07:07
# 4                                ['dkpol', 'COVID19dk']  2021-08-16 15:48:37
# ...                                                 ...                  ...
# 1731                                                 []  2021-08-11 18:48:21
# 1732                                                 []  2021-08-11 17:59:14
# 1733  ['dkpol', 'dkmedier', 'coronadk', 'covid19dk',...  2021-08-11 17:50:59
# 1734                   ['dkpol', 'dkmedier', 'COVID19']  2021-08-10 19:29:12
# 1735  ['dkpol', 'dkmedier', 'COVID19dk', 'coronadk',...  2021-08-09 16:41:59
#
# [1736 rows x 11 columns]

# %% [markdown]
# ### Cleaning the DataFrame

# %%
#Emoji patterns
emoji_pattern = re.compile("["
         u"\U0001F600-\U0001F64F"  # emoticons
         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
         u"\U0001F680-\U0001F6FF"  # transport & map symbols
         u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
         u"\U00002702-\U000027B0"
         u"\U000024C2-\U0001F251"
         "]+", flags=re.UNICODE)

# %%
#Dropping collumns
data_set1 = data_set.drop(['Unnamed: 0','username', 'description', 'followers', 'following'], axis=1).reset_index(drop = True)

#Creating collumn for hashtags
data_set1['hashtags'] = data_set1['text'].apply(lambda x: re.findall(r'#(\w+)', x))

#Calling text column
tweets = data_set1.text.values[0]

# %%
import numpy as np

def clean_tweet(tweet):
    if type(tweet) == np.float64:
        return ""
    temp = tweet.lower()
    temp = re.sub("'", "", temp) 
    temp = re.sub("@[A-Za-z0-9_]+","", temp)
    temp = re.sub("#[A-Za-z0-9_]+","", temp)
    temp = re.sub(r'http\S+', '', temp)
    temp = re.sub('[()!?]', ' ', temp)
    temp = re.sub('[-.,*:]',' ', temp)
    temp = re.sub('\v', ' ', temp)
    temp = re.sub("[\\n]"," ", temp)
    return temp

clean_data = [clean_tweet(tweets) for tweet in tweets]

# %%
tweets = [None for i in range(len(data_set1))]
#ny = [None for i in range(len(data_set1))]
score = [None for i in range(len(data_set1))]
for i in range(len(data_set1)):  
    tweets[i] = clean_tweet(data_set1.text.values[i])
    score[i]= afinn.score(tweets[i])
   
   
tweets
# Out:
# ['beder alle indberette dette tweet  da det tydeligt opfordrer til overgreb  tvang og vold mod børn og unge  bør ikke høre hjemme på sociale medier        hvad er det for nogle monstre i har skabt   ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'indsatsen i afghanistan har kostet danmark 15 milliarder kr  de sidste 20 år   det samme beløb som vi har brugt på 6 5 måned på coronahåndteringen    det var bare det ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'her kan en ny nedlukning være på vej    ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'hvilken dansk politiker har de stærkeste anti lockdown  anti covidpas  anti covidhysteri holdninger   ',
#  '  reminder om  at det er vigtigt  at vi ikke bare tænker i folk  der skal indlægges eller blir alvorligt syge  det handler i stor grad om  at undgå at folk overhovedet smittes    ',
#  'jeg har fået feber efter min anden dosis moderna  det er fint nok  men det er jævnt irriterende  at både min overbo og underbo så vælger at fyre op for hver sin technofest netop i aften  så  kan vi ikke få genindført de restriktioner  🤣  ',
#  ' klart i er  klart i er  en "vaccine" som har eksisteret i mindre end et år har i viden om er fuldstændigt sikkert bare to år frem   sounds legit        ',
#  'sars cov 2 findes ikke  ingen virus  ingen pandemi  i er blevet røvrendt for jeres egne skattekroner     ',
#  'sars cov 2 findes ikke  ingen virus  ingen pandemi  i er blevet røvrendt for jeres egne skattekroner     ',
#  'sars cov 2 findes ikke  ingen virus  ingen pandemi  i er blevet røvrendt for jeres egne skattekroner     ',
#  'jeg er overrasket over hvor mange i dk der rent faktisk hylder det totalitærer og diktatorisk  imens de mener at de samtidig står op for demokratiet   🤔   det hænger simpelthen ikke sammen   🤷🏽\u200d♂️     ',
#  'sars cov 2 findes ikke  ingen virus  ingen pandemi  i er blevet røvrendt for jeres egne skattekroner     ',
#  'beder alle indberette dette tweet  da det tydeligt opfordrer til overgreb  tvang og vold mod børn og unge  bør ikke høre hjemme på sociale medier        hvad er det for nogle monstre i har skabt   ',
#  'en historie fra det virkelige liv     ',
#  'dansk politik er under coronakrisen blevet overtaget af en skadelig biopolitik baseret på tre totalitære tendenser  det lover dårligt for fremtiden  skriver thomas aastrup rømer i dette debatindlæg     ',
#  'sars cov 2 findes ikke  ingen virus  ingen pandemi  i er blevet røvrendt for jeres egne skattekroner     ',
#  'dansk politik er under coronakrisen blevet overtaget af en skadelig biopolitik baseret på tre totalitære tendenser  det lover dårligt for fremtiden  skriver thomas aastrup rømer i dette debatindlæg     ',
#  'så når jeg hopper på toget i morgen  er jeg fri for at høre på en eller anden stor mand stå og udskamme mig med hans ord og hans blik  interessant  det er da første gang i ca et år det sker        ',
#  'myanmars fagbevægelse  militæret har forværret epidemien  men arbejdsgiverne har også et ansvar     ',
#  'fra lørdag er det slut med mundbind i kollektiv transport  kæmpe tak til transportører  medarbejdere og borgere  der gennem hele coronakrisen har holdt ud i nu mere end et år  i har været med til at få os igennem coronakrisen    ',
#  'fra lørdag er det slut med mundbind i kollektiv transport  kæmpe tak til transportører  medarbejdere og borgere  der gennem hele coronakrisen har holdt ud i nu mere end et år  i har været med til at få os igennem coronakrisen    ',
#  'fra lørdag er det slut med mundbind i kollektiv transport  kæmpe tak til transportører  medarbejdere og borgere  der gennem hele coronakrisen har holdt ud i nu mere end et år  i har været med til at få os igennem coronakrisen    ',
#  'fra lørdag er det slut med mundbind i kollektiv transport  kæmpe tak til transportører  medarbejdere og borgere  der gennem hele coronakrisen har holdt ud i nu mere end et år  i har været med til at få os igennem coronakrisen    ',
#  'fra lørdag er det slut med mundbind i kollektiv transport  kæmpe tak til transportører  medarbejdere og borgere  der gennem hele coronakrisen har holdt ud i nu mere end et år  i har været med til at få os igennem coronakrisen    ',
#  'fra lørdag er det slut med mundbind i kollektiv transport  kæmpe tak til transportører  medarbejdere og borgere  der gennem hele coronakrisen har holdt ud i nu mere end et år  i har været med til at få os igennem coronakrisen    ',
#  'en historie fra det virkelige liv     ',
#  'fra lørdag er det slut med mundbind i kollektiv transport  kæmpe tak til transportører  medarbejdere og borgere  der gennem hele coronakrisen har holdt ud i nu mere end et år  i har været med til at få os igennem coronakrisen    ',
#  'fra lørdag er det slut med mundbind i kollektiv transport  kæmpe tak til transportører  medarbejdere og borgere  der gennem hele coronakrisen har holdt ud i nu mere end et år  i har været med til at få os igennem coronakrisen    ',
#  'pressede betjente slår hårdest mød politiet med kærlighed og åbne arme     ',
#  'covid 19 smitter særlig meget ved sang indendørs ørnenemodcovid19  åren         ',
#  'og selvfølgelig er cepos med på den vogn  her bestyrelsesmedlem christian bjørnskov  skammeligt     ',
#  'og selvfølgelig er cepos med på den vogn  her bestyrelsesmedlem christian bjørnskov  skammeligt     ',
#  'dybt uansvarligt og nærmest kriminel timing  situationen i florida og texas taget i betragtning  hvordan kan denne mand dog være en amerikansk senator    ',
#  'covid 19 smitter særlig meget ved sang indendørs ørnenemodcovid19  åren         ',
#  '  det var da godt nok pudsigt  når befolkningen bliver tvunget til at bruge den     ',
#  'presset på regeringen stiger  viser en rundspørge som indblik har foretaget  se her  hvilke partier  der er med på at sløjfe coronarestriktionerne fuldstændigt      ',
#  'presset på regeringen stiger  viser en rundspørge som indblik har foretaget  se her  hvilke partier  der er med på at sløjfe coronarestriktionerne fuldstændigt      ',
#  ' måske ikke lige den mest troværdige person denne thomas teglgård    ',
#  'anastasia loupis taler på råshuspladsen  vaccinationsforsøg uden informeret samtykke     ',
#  'ja så mangler vi bare at fjerne mundbind i den offentlige transport  så er vi ved at være der  ',
#  ' tsk tsk  der er ingen der giver en døjt for restriktioner  befolkningen er videre  regeringen skal finde tilbage til virkeligheden   ',
#  'hvis det stod til liberal alliances partileder alex vanopslagh  ville alle coronarestriktioner være væk i morgen  det fortæller han i et interview med indblik      ',
#  'stærk udmelding fra        ',
#  'pandemien er ikke overstået    er her stadig  så husk det  situationen er ikke ligesom sidste år  selvom du er vaccineret  så skal du stadig tænke dig om  et stik er ikke nok  du skal ha to   og selvom du har fået dem  så tænk dig om    ',
#  'stærk udmelding fra        ',
#  'hvis det stod til liberal alliances partileder alex vanopslagh  ville alle coronarestriktioner være væk i morgen  det fortæller han i et interview med indblik      ',
#  'stærk udmelding fra        ',
#  'stærk udmelding fra        ',
#  'stærk udmelding fra        ',
#  'hvis det stod til liberal alliances partileder alex vanopslagh  ville alle coronarestriktioner være væk i morgen  det fortæller han i et interview med indblik      ',
#  'sagde manden lige 95% af alle over 12 år skal være vaccineret før end hr   er tilfreds   hvilket argument ligger dog til grund for lige netop det tal   lyder mere som er politisk mål  fremfor et sundhedsfagligt logisk mål      ',
#  'til alle jer præster  hvad skete der  gik luther himself ikke op md overmagten  hvorfor lader i nogle latterlige politikkere på christiansborg knægte jeres sognebørn på denne usle vis  hold dog for pokker de konfirmationer    ',
#  'sådan 👊🏼  forklaret på 6 minutter       ',
#  'sådan 👊🏼  forklaret på 6 minutter       ',
#  'sådan 👊🏼  forklaret på 6 minutter       ',
#  'dørene åbnes nu på vid gab i langt størstedelen af vores vaccinationscentre i region sjælland  i 20 vaccinationscentre   mindst ét i hver kommune   kan borgere blive vaccineret mod covid 19 uden tidsbestilling fra den 9/8      ',
#  'hvad mener du  bør vi også vaccinere børn under 12 år mod corona      ',
#  'hvad mener du  bør vi også vaccinere børn under 12 år mod corona      ',
#  'hvad mener du  bør vi også vaccinere børn under 12 år mod corona      ',
#  '        tal for dig selv  jeg vil gerne have dem ',
#  ' vi behøver ikke de her opdateringer  de sårbare er vaccineret/tilbudt vaccine for længe siden  det er de unge ikke sårbare hvor medicinske eksperter siger de slet ikke er bekymrede  der er ikke pres på hospitaler   tværtimod  kom nu videre     ',
#  'danmark ligger i henholdsvis top 10 og top 20 i international sammenhæng  når man ser på  hvor store andele af befolkningen der har fået ét eller to vaccinestik mod covid 19       ',
#  'danmark ligger i henholdsvis top 10 og top 20 i international sammenhæng  når man ser på  hvor store andele af befolkningen der har fået ét eller to vaccinestik mod covid 19       ',
#  'det bør stå klart  at det ikke først er under coronakrisen  at ufriheden har gjort sit indtog  den har haft tag i os alt for længe  skriver chefredaktør claes theilgaard i denne leder     ',
#  'det bør stå klart  at det ikke først er under coronakrisen  at ufriheden har gjort sit indtog  den har haft tag i os alt for længe  skriver jeg i dagens leder på      ',
#  'klar tale fra   har han ret      ',
#  'det bør stå klart  at det ikke først er under coronakrisen  at ufriheden har gjort sit indtog  den har haft tag i os alt for længe  skriver jeg i dagens leder på      ',
#  'det bør stå klart  at det ikke først er under coronakrisen  at ufriheden har gjort sit indtog  den har haft tag i os alt for længe  skriver chefredaktør claes theilgaard i denne leder     ',
#  'det bør stå klart  at det ikke først er under coronakrisen  at ufriheden har gjort sit indtog  den har haft tag i os alt for længe  skriver chefredaktør claes theilgaard i denne leder     ',
#  'klar tale fra   har han ret      ',
#  'corona restriktionerne har udviklet sig til et absurd cirkus  regler skal give mening ellers mister myndighederne enhver troværdighed og autoritet    dette har  desværre endnu ikke forstået en klap af     ',
#  'klar tale fra   har han ret      ',
#  'klar tale fra   har han ret      ',
#  'næh dog  børn blir syge og dør af  i indien  ingen reaktion  den samme variant  overtager i vesten og børn begynder at blive alvorligt syge    surprisedpicachu jpg    ',
#  'næh dog  børn blir syge og dør af  i indien  ingen reaktion  den samme variant  overtager i vesten og børn begynder at blive alvorligt syge    surprisedpicachu jpg    ',
#  'mette fik chancen for at bide til bavarian nordics covid 19 vaccine bolle  valgte en hygge tur til israel  brugte dyrbar tid på some med makrelmadder  fodbold og ol  nu er løbet kørt  risikoen ved investeringen er med dagens resultater reduceret og prisen steget  ',
#  '   er det diskriminerende og ulovligt hvis man afviser at ansætte en medarbejder der ikke vil vaccineres mod covid19  er det diskriminerende og ulovligt  hvis jeg i mit hjem  selv bestemmer hvilket klientel jeg lukker ind ',
#  'han mener ikke  covid19 er relevant i afghanistan  er han så en slags "corona benægter" 🤔 ',
#  '  jeg troede  covid19 var liv eller død ',
#  ' thol’kuthi hey…bekuvele kubheda before covid19 happened 🤣💀😭',
#  'vaccinekrav fra arbejdsgiver er ikke i orden   advarer sammen med  og  genmab mod at stille krav om vaccine til medarbejdere     ',
#  'coronakommission i dk nu   det skal være langt bredere end minksagen og involvere epidemilov  sygdomskategori  demokratiet  medicinalindustriens magt  masseudrulning af nødgodkendte vacciner osv     ',
#  '     jet fuel cant melt bijlmer flats',
#  ' hvad er covid19 situationen i afghanistan ',
#  'pandemix center stiller med et team til  aarhus covid 19 datathon 2021  vi glæder os til at dykke ned i de mange spændende  data vi har i dk i samspil med andre  @ aarhusuni_int ',
#  'biomarkøren supar    udviklet her hos os af blandt andre forskningsleder  professor ove andersen   viste potentiale under covid 19  \u200b\u200bkan hjælpe akutmodtagelsen med at finde de patienter  der har behov for indlæggelse og behandling    ',
#  'pandemix center stiller med et team til  aarhus covid 19 datathon 2021  vi glæder os til at dykke ned i de mange spændende  data vi har i dk i samspil med andre  @ aarhusuni_int ',
#  '  artiklen handler om behandling af covid19 og ikke om vacciner ',
#  ' hvilken fejl har de så begået i israel   ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'det her er vist den første videnskabelige artikel  der viser  hvad der længe har været opfattelsen  at vaccinerede med breakthrough infektion udskiller lige så mange vira som uvaccinerede med infektion         ',
#  '     ja det går skidt i israel nu  nye studier fra israel viser dog  at vaccinerede har 8 gange mindre risiko for at få et svært covid19 forløb ved smitte  er du vaccineret pia  jeg er selv ',
#  'vaccinekrav fra arbejdsgiver er ikke i orden   advarer sammen med  og  genmab mod at stille krav om vaccine til medarbejdere     ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'vaccinekrav fra arbejdsgiver er ikke i orden   advarer sammen med  og  genmab mod at stille krav om vaccine til medarbejdere     ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'vi møder de unge dér  hvor de er  i denne uge åbner region sjælland pop up vaccinationscentre på uddannelsesinstitutioner yderligere 13 forskellige steder  her taler en af vores medarbejdere med en elev på slotshaven gymnasium i holbæk i sidste uge    ',
#  'vi stod i front under epidemien  men nu bliver vi smidt væk "  ruth rasmussen er den seneste i rækken af fortællinger om frontpersonale  der oplever at blive ramt økonomisk pga   senfølger     ',
#  'ansigtsmasker har som bekendt ingen dokumenterbar effekt på smittespredning af coronavirus    heller ikke i malaysia  8/1/20 betyder 01 08 2020         ',
#  'kina anerkender talebans overtagelse af afghanistan og er begyndt diplomatiske forbindelser med dem    taleban har   angiveligt   forbudt covid19   vaccinen    og sådan fandt corona hjem igen  slut',
#  'vi ta’r en tur i tidsmaskinen i dag… ligesom både fodbold em 2020 og ol 2020 blev afholdt i 2021 pga  er det i dag  “delegeretmøde nov 2020”  lokalformænd fra hele landet samles på nyborg strand  mindset; beretning er om 2020  fremtid er 2021  ',
#  '      lad os nu bare tage et  for at få renset luften efter   ',
#  'coronakommission i dk nu   det skal være langt bredere end minksagen og involvere epidemilov  sygdomskategori  demokratiet  medicinalindustriens magt  masseudrulning af nødgodkendte vacciner osv     ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'coronakommission i dk nu   det skal være langt bredere end minksagen og involvere epidemilov  sygdomskategori  demokratiet  medicinalindustriens magt  masseudrulning af nødgodkendte vacciner osv     ',
#  ' jeg vil også rigtig gerne vide  hvor stor % af de indlagte er vaccinerede  og så må det efter 1 5 år være muligt først og fremmest at sortere alle fra  der er indlagt af anden årsag  indtil da er tallet ubrugeligt   ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'fascinating data analysis here ',
#  'beder alle indberette dette tweet  da det tydeligt opfordrer til overgreb  tvang og vold mod børn og unge  bør ikke høre hjemme på sociale medier        hvad er det for nogle monstre i har skabt   ',
#  'fascinating data analysis here ',
#  '🤔 national center for disaster    ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'fascinerende og bekymrende læsning      [for mere viden om ebv og monokleose   ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  ' du må da være gal i hovedet   fyldt af storhed  s  vanvid          ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'måske alle vaccinerede kvinder burde nægte at date de uvaccinerede  det eneste der som bekendt er vigtigere for mange unge mænd end alt andet  inkl  angst for at virke svag  er jo sex  så måske et "nej tak til ikke vax" vil få dk helt i top      ',
#  'bare for en god ordens skyld  i maj 2021 fremhævede nordisk råd danmark for at have givet mest økonomisk støtte til kulturlivet ifm      ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'opdateret status  uændret generelt billede for bivirkninger efter vaccination mod   langt de fleste bivirkninger er kendte og forbigående  de 12 15 årige udviser samme bivirkningsprofil som befolkningen som helhed  læs mere   ',
#  'in  era   analysis   in   v/                     ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  ' årsagen er  at vi tester mere i 2021 med de elendige pcr tests  som skaber myriader af falske positive cases   når en positiv så indlægges med andre ting   brækket ben f eks   bliver han alligevel reg  som covid19 patient   sådan skabes en case demic ',
#  'in  era   analysis   in   v/                     ',
#  'in  era   analysis   in   v/                     ',
#  'the international federation of red cross and red crescent societies siger det her   men her i danmark er covid 19 forbi             ',
#  'på nuværende tidspunkt kommer det næppe bag på nogen  at bodega virologerne i cepos ikke forstår noget  gud være lovet  at ingen i en ansvarsfuld position har lyttet til dem  så ville vi have haft 10 000 døde i danmark i stedet for 2500      ',
#  ' min kollega  fik en blodprop i hjernen efter vaccinen mod covid19  hun blev indlagt på rigshospitalet  hun er 30 år ',
#  'det fedeste ved placebo effekten er at den virker  selvom vi ved at vi ikke bliver behandlet  jeg havde milde forkølelsessymptomer  så selvom jeg er vaccineret  blev jeg testet  da jeg fik negativ svaret  fik jeg det bedre  nogen har undersøgt mig  så det går nok   ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  '2/n  vi ved det naturligvis godt  men det her er blot endnu en understregning af  at coronapas er meningsløse    og oveni er de også diskriminerende    folketingets beslutning om dem er en skamplet for folkestyret        ',
#  'det her er vist den første videnskabelige artikel  der viser  hvad der længe har været opfattelsen  at vaccinerede med breakthrough infektion udskiller lige så mange vira som uvaccinerede med infektion         ',
#  '    jeg tror også at vaccinationen vil hjælpe den enkelte  til at få et meget nemmere covid19 sygdomsforløb  hvis man skulle være uheldig  at blive smittet med corona og det gælder nærmest alle aldersgrupper  pånær måske børnene ',
#  '2/n  vi ved det naturligvis godt  men det her er blot endnu en understregning af  at coronapas er meningsløse    og oveni er de også diskriminerende    folketingets beslutning om dem er en skamplet for folkestyret        ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'trods den voksende vaccineudrulning verden over peger mere og mere på  at vi kommer til at leve med covid 19 i årtier fremover     ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  '2 5 4% af alle uvaccinerede personer på 20 29 vil blive indlagt hvis de smittes med delta varianten  det er 2 3 gange flere end med den britiske variant    ',
#  'taliban   nog sneller dan de ',
#  'nu 3 smittede i søns 9 klasse  onlineskole igen 😩 ',
#  'trods den voksende vaccineudrulning verden over peger mere og mere på  at vi kommer til at leve med covid 19 i årtier fremover     ',
#  'nej tak  genmab  det er ufatteligt udansk at tvinge medarbejderne til at lade sig covid 19 vaccinere   laboranterne evner nemlig at tage en egen helbredsmæssig vurdering om de har brug for at lade sig vaccinere mod covid 19    ',
#  'vi beholder afstandsmarkeringer osv indtil videre 👍     ',
#  'nej tak  genmab  det er ufatteligt udansk at tvinge medarbejderne til at lade sig covid 19 vaccinere   laboranterne evner nemlig at tage en egen helbredsmæssig vurdering om de har brug for at lade sig vaccinere mod covid 19    ',
#  '2/n  vi ved det naturligvis godt  men det her er blot endnu en understregning af  at coronapas er meningsløse    og oveni er de også diskriminerende    folketingets beslutning om dem er en skamplet for folkestyret        ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  '2/n  vi ved det naturligvis godt  men det her er blot endnu en understregning af  at coronapas er meningsløse    og oveni er de også diskriminerende    folketingets beslutning om dem er en skamplet for folkestyret        ',
#  'bare for en god ordens skyld  i maj 2021 fremhævede nordisk råd danmark for at have givet mest økonomisk støtte til kulturlivet ifm      ',
#  'bare for en god ordens skyld  i maj 2021 fremhævede nordisk råd danmark for at have givet mest økonomisk støtte til kulturlivet ifm      ',
#  'er  også droppet  som følge af de fjernede restriktioner      ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  ' årsagen er  at vi tester mere i 2021 med de elendige pcr tests  som skaber myriader af falske positive cases   når en positiv så indlægges med andre ting   brækket ben f eks   bliver han alligevel reg  som covid19 patient   sådan skabes en case demic ',
#  'på nuværende tidspunkt kommer det næppe bag på nogen  at bodega virologerne i cepos ikke forstår noget  gud være lovet  at ingen i en ansvarsfuld position har lyttet til dem  så ville vi have haft 10 000 døde i danmark i stedet for 2500      ',
#  'indlagte lige nu 117 heraf 15 på intensiv  og alligevel forsøger  med de sidste krampetrækninger at holde frugten i live 🤯          ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  '3/ læs hvordan andre lande arbejder for et bedre indeklima her   australien   ørnenemodcovid19    ',
#  '2/ skoler og institutioner bør prioritere    💙 co2 målere  der viser hvornår luftkvaliteten er for dårlig   💙 åbne vinduer  💙 elektrisk ventilation og luftrensere  til at hjælpe hvis åbne vinduer ikke er nok  ørnenemodcovid19   ',
#  'covid19 er luftbåren og derfor er god luftkvalitet en af de bedste måder at forebygge smittespredning  på  et godt indeklima forebygger ikke bare smittespredning  det fører også til bedre koncentration og mindre træthed  ørnenemodcovid19    ',
#  'indsatsen i afghanistan har kostet danmark 15 milliarder kr  de sidste 20 år   det samme beløb som vi har brugt på 6 5 måned på coronahåndteringen    det var bare det ',
#  '  kun 100 mio € kan relateres til covid19  laporta siger 200 mio € på lønbudget men uden at sælge stjerner  messi er røget så det er vel 60 mio €ish  hvordan vil man finde knap 150 mio € yderligere på marginalspillere som ingen gider  😅',
#  '2/n  vi ved det naturligvis godt  men det her er blot endnu en understregning af  at coronapas er meningsløse    og oveni er de også diskriminerende    folketingets beslutning om dem er en skamplet for folkestyret        ',
#  'vi møder de unge dér  hvor de er  i denne uge åbner region sjælland pop up vaccinationscentre på uddannelsesinstitutioner yderligere 13 forskellige steder  her taler en af vores medarbejdere med en elev på slotshaven gymnasium i holbæk i sidste uge    ',
#  '      og  må researche inden de interviewer  de vil hurtigt opdage  at påståede fordele ved "naturlig immunitet" står øverst på who’s liste over myter og misforståelser         ',
#  '2/n  vi ved det naturligvis godt  men det her er blot endnu en understregning af  at coronapas er meningsløse    og oveni er de også diskriminerende    folketingets beslutning om dem er en skamplet for folkestyret        ',
#  'ansigtsmasker har som bekendt ingen dokumenterbar effekt på smittespredning af coronavirus    heller ikke i malaysia  8/1/20 betyder 01 08 2020         ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  '    og israel truer allerede med lock down  når lambda rammer dem               ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  ' hb 16 aug 2021 ',
#  '🤔 ledende overlæge siger  det ikke ser ud til stigning  men at vi først vil kunne se det om et par uger🤷🏻\u200d♂️   ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'her kan en ny nedlukning være på vej    ',
#  'det her er vist den første videnskabelige artikel  der viser  hvad der længe har været opfattelsen  at vaccinerede med breakthrough infektion udskiller lige så mange vira som uvaccinerede med infektion         ',
#  'bare for en god ordens skyld  i maj 2021 fremhævede nordisk råd danmark for at have givet mest økonomisk støtte til kulturlivet ifm      ',
#  'det her er vist den første videnskabelige artikel  der viser  hvad der længe har været opfattelsen  at vaccinerede med breakthrough infektion udskiller lige så mange vira som uvaccinerede med infektion         ',
#  '2/n  vi ved det naturligvis godt  men det her er blot endnu en understregning af  at coronapas er meningsløse    og oveni er de også diskriminerende    folketingets beslutning om dem er en skamplet for folkestyret        ',
#  'det her er vist den første videnskabelige artikel  der viser  hvad der længe har været opfattelsen  at vaccinerede med breakthrough infektion udskiller lige så mange vira som uvaccinerede med infektion         ',
#  '2/n  vi ved det naturligvis godt  men det her er blot endnu en understregning af  at coronapas er meningsløse    og oveni er de også diskriminerende    folketingets beslutning om dem er en skamplet for folkestyret        ',
#  '      og  må researche inden de interviewer  de vil hurtigt opdage  at påståede fordele ved "naturlig immunitet" står øverst på who’s liste over myter og misforståelser         ',
#  'underretninger er socialrådgivernes mulighed for at få kendskab til og handle når børn er i nød   har været hård for mange familier og de der er tæt på børnene bør have en skærpet opmærksomhed  ørneneførst  ',
#  'sommerferien er ved at være brugt op for de fleste  og derfor har vi justeret vores tilbud om hurtigtest mod   for eksempel er teststedet i fårup sommerland lukket  tjek hele den justerede plan  ',
#  '… men er det en utopi at leve i håbet om den fjerde statsmagts genopståen         ',
#  'den etablerede presses kritikløse kolportering af coronainfo medfører også noget godt    erkendelsen af at kritisk journalistik ikke eksisterer i den etablerede presse    den viden frigør en masse tid    perfekt        ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'ca  42 000 stik i går og endnu en dag med fokus på at genvaccinere folk  idet kun 4 505 påbegyndte vaccination i går    ',
#  'musculoskeletal  msk  funding opens               ',
#  'vi møder de unge dér  hvor de er  i denne uge åbner region sjælland pop up vaccinationscentre på uddannelsesinstitutioner yderligere 13 forskellige steder  her taler en af vores medarbejdere med en elev på slotshaven gymnasium i holbæk i sidste uge    ',
#  'bare for en god ordens skyld  i maj 2021 fremhævede nordisk råd danmark for at have givet mest økonomisk støtte til kulturlivet ifm      ',
#  'obs   en ganske interessant meta deskriptiv konference om data  danskere og covid19 står til at foregå den kommende weekend  det kunne være rart at have tid at være en flue på væggen der   ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'dagens  tal d  16/8  i dag ingen dødsfald  det giver altid 💚  men 959 nye coronatilfælde  svarende til 16 4 ‰ af godt 58 000 tests  117 patienter er indlagt  der kom 33 nye til  sølle 4521 fik første stik i går  og der er 12 996 aktivt syge  ihad  🔴🔴🔴💚  ',
#  'ca  42 000 stik i går og endnu en dag med fokus på at genvaccinere folk  idet kun 4 505 påbegyndte vaccination i går    ',
#  '   det er præcis den slags jeg hentyder til🤷\u200d♀️der kan gøres mere  konsekvenserne kan blive store  dk er berygtet for sin manglende håndtering af postvirale senfølger  længe før covid19 ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'det her ser dælme ikke godt ud  stadig omkring 1000 smittede hver dag og nu 10 mere indlagte og en i respirator    det er slet ikke godt nyt      ',
#  'sommerferien er ved at være brugt op for de fleste  og derfor har vi justeret vores tilbud om hurtigtest mod   for eksempel er teststedet i fårup sommerland lukket  tjek hele den justerede plan  ',
#  '1/3  breaking  nye corona tal i dk    positive tests seneste døgn  959  i går  850  tests  pcr  seneste døgn  58306  gns  7 dage  60827  positiv %  pcr  seneste døgn  1 64  gns  7 dage  1 66  døde seneste døgn  0  i alt  2560   kilde   ',
#  'vi møder de unge dér  hvor de er  i denne uge åbner region sjælland pop up vaccinationscentre på uddannelsesinstitutioner yderligere 13 forskellige steder  her taler en af vores medarbejdere med en elev på slotshaven gymnasium i holbæk i sidste uge    ',
#  'den tyske regering bad forskerne fra robert koch instituttet om at dramatisere corona på en måde der kunne legitimisere ting som nedlukninger  smag lidt på den     ',
#  'vi møder de unge dér  hvor de er  i denne uge åbner region sjælland pop up vaccinationscentre på uddannelsesinstitutioner yderligere 13 forskellige steder  her taler en af vores medarbejdere med en elev på slotshaven gymnasium i holbæk i sidste uge    ',
#  'vi møder de unge dér  hvor de er  i denne uge åbner region sjælland pop up vaccinationscentre på uddannelsesinstitutioner yderligere 13 forskellige steder  her taler en af vores medarbejdere med en elev på slotshaven gymnasium i holbæk i sidste uge    ',
#  ' situation in myanmar        ',
#  'mange ældre er blevet svækkede under   fordi de været isoleret og deres daglige træning og aktiviteter har været aflyst  vi opfordrer sammen med  i  til politisk handling  og at man som pårørende er opmærksom   ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  ' sande positive pcr tests optræder helt overvejende hos personer med relevante symptomer  men testen kan være sandt positiv uden symptomer  se b herunder  a viser at 4 ud af 8 asymptomatiske vaccinerede har ct&lt;25         ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'er der danske politikere og sundhedsmyndigheder  der nu med snart 20 mdrs  latenstid vil begynde at forholde sig til virkeligheden          ',
#  'sommerferien er ved at være brugt op for de fleste  og derfor har vi justeret vores tilbud om hurtigtest mod   for eksempel er teststedet i fårup sommerland lukket  tjek hele den justerede plan  ',
#  '    min kollega på 30 fik en blodprop i hjernen efter vaccinen mod covid19  hun blev indlagt på rigshospitalet  de afviser at indberette som vaccineskade  da det ikke kan udelukkes at den er stress udløst  hun har selv lavet en uth ',
#  'vi beholder afstandsmarkeringer osv indtil videre 👍     ',
#  'ansigtsmasker har som bekendt ingen dokumenterbar effekt på smittespredning af coronavirus    heller ikke i malaysia  8/1/20 betyder 01 08 2020         ',
#  'er der danske politikere og sundhedsmyndigheder  der nu med snart 20 mdrs  latenstid vil begynde at forholde sig til virkeligheden          ',
#  '   det er ik sådan så en virus tænker nu er folk blevet vaccineret så nu må jeg hellere mutere  det er mere et sandsynlighedens spil da covid19 ofte mutere  og dette sker nå en ny person bliver smittet  så jo flere smittet  jo mere sandsynligt for en version hvor vaccinen ik virker ',
#  'også unge mennesker uden vaccination kan blive alvorligt syge af den dominerende deltavariant  som ifølge statens serum institut giver en tre gange øget risiko for at blive indlagt  afdelingschef tyra grove krause tør ikke udelukke  at det kan blive     ',
#  'det her er vist den første videnskabelige artikel  der viser  hvad der længe har været opfattelsen  at vaccinerede med breakthrough infektion udskiller lige så mange vira som uvaccinerede med infektion         ',
#  'også unge mennesker uden vaccination kan blive alvorligt syge af den dominerende deltavariant  som ifølge statens serum institut giver en tre gange øget risiko for at blive indlagt  afdelingschef tyra grove krause tør ikke udelukke  at det kan blive     ',
#  'jeg får stadig aflyst en del tider grundet covid19 isolation   jeg forstår godt det der med at det er nødvendigt og alt det der   men det er godt nok stadig dyrt at for mange af os små selvstændige ',
#  '  dog ikke covid19   han er nok snart væk fra brøndby ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  '    cabinet minister portfolios reshuffled  amidst     ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'die sanger steve hofmeyr het maandagoggend op sy facebook blad geskryf hy ervaar tans ernstige covid 19 simptome  ➡️  |    ',
#  'jeg vil anbefale alle til  at se denne video  det er en opsummering af begivenhedernes gang siden 2020  og den får tingene til at hænge sammen  se den hele  det vil være en øjenåbner for de fleste   ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'nyttig viden om sygehustestning  troede faktisk ikke det stod så slemt til  teststrategien er fuldkommen irrationel som det fremgår af artiklen her           ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'mange ældre er blevet svækkede under   fordi de været isoleret og deres daglige træning og aktiviteter har været aflyst  vi opfordrer sammen med  i  til politisk handling  og at man som pårørende er opmærksom   ',
#  'die sanger steve hofmeyr het maandagoggend op sy facebook blad geskryf hy ervaar tans ernstige covid 19 simptome  ➡️  |    ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'ansigtsmasker har som bekendt ingen dokumenterbar effekt på smittespredning af coronavirus    heller ikke i malaysia  8/1/20 betyder 01 08 2020         ',
#  'die sanger steve hofmeyr het maandagoggend op sy facebook blad geskryf hy ervaar tans ernstige covid 19 simptome  ➡️  |    ',
#  'ser til min mindste overraskelse  at alle eksperterne på covid19 vaccineringen/klimaforandringerne/ligestilling og skattelovgivning naturligvis også er eksperter på afghanistan og udenrigspolitik ',
#  'få din vaccination uden tidsbestilling  der er drop in vaccination alle dage 9 18 i vaccinationscentrene i region hovedstaden  på  er der drop in alle dage 9 16  se åbningstider i dit lokale vaccinecenter       ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'die sanger steve hofmeyr het maandagoggend op sy facebook blad geskryf hy ervaar tans ernstige covid 19 simptome  ➡️  |    ',
#  'die sanger steve hofmeyr het maandagoggend op sy facebook blad geskryf hy ervaar tans ernstige covid 19 simptome  ➡️  |    ',
#  'die sanger steve hofmeyr het maandagoggend op sy facebook blad geskryf hy ervaar tans ernstige covid 19 simptome  ➡️  |    ',
#  'die sanger steve hofmeyr het maandagoggend op sy facebook blad geskryf hy ervaar tans ernstige covid 19 simptome  ➡️  |    ',
#  'die sanger steve hofmeyr het maandagoggend op sy facebook blad geskryf hy ervaar tans ernstige covid 19 simptome  ➡️  |    ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'myocarditis og pericarditis efter vaccination for covid 19  5 7 indlæggelser pr  10 000 vaccinerede  myocarditis med overvægt af yngre mænd    indlæggelser underestimerer det reelle antal         ',
#  'hvilken dansk politiker har de stærkeste anti lockdown  anti covidpas  anti covidhysteri holdninger   ',
#  'the international federation of red cross and red crescent societies siger det her   men her i danmark er covid 19 forbi             ',
#  'ansigtsmasker har som bekendt ingen dokumenterbar effekt på smittespredning af coronavirus    heller ikke i malaysia  8/1/20 betyder 01 08 2020         ',
#  'the international federation of red cross and red crescent societies siger det her   men her i danmark er covid 19 forbi             ',
#  'jeg vil anbefale alle til  at se denne video  det er en opsummering af begivenhedernes gang siden 2020  og den får tingene til at hænge sammen  se den hele  det vil være en øjenåbner for de fleste   ',
#  '"wauw   holder ikke længere øko nede  for kort tid siden var vi ramt af restriktioner og mangel på efterspørgsel  mangel på materialer og arbejdskraft er nu de største udfordringer " siger    ',
#  '"wauw   holder ikke længere øko nede  for kort tid siden var vi ramt af restriktioner og mangel på efterspørgsel  mangel på materialer og arbejdskraft er nu de største udfordringer " siger    ',
#  '"wauw   holder ikke længere øko nede  for kort tid siden var vi ramt af restriktioner og mangel på efterspørgsel  mangel på materialer og arbejdskraft er nu de største udfordringer " siger    ',
# ...
#  ' ansat på laboratorie i  kan være smittet af flagermus som den første  siger dansk who chef ',
#  '1/n  det er en skandale  at der ikke er udført en systematisk undersøgelse af koagulationssystemsaktivering før vaccinegodkendelserne    og at de regulatoriske myndigheder har godkendt vaccinerne på trods af det        ',
#  'direktør  har i dag vaccineret elever i pop up vaccinationscenteret på euc nordvestsjælland og slotshaven gymnasium i holbæk  det er en del af indsatsen for at øge vaccinationstilslutningen blandt unge  og tak til alle jer  der tog imod tilbuddet💪 ',
#  'direktør  har i dag vaccineret elever i pop up vaccinationscenteret på euc nordvestsjælland og slotshaven gymnasium i holbæk  det er en del af indsatsen for at øge vaccinationstilslutningen blandt unge  og tak til alle jer  der tog imod tilbuddet💪 ',
#  'fordi man ikke skal holde afstand  betyder det ikke  at man ikke må  højeste antal smittede i 2 uger og højeste antal indlagte i 2 mdr  ifølge radioavisen lige nu  noget føles lidt off      ',
#  '2/n  2  hvorfor går de ud fra  nedlukninger virker  når der er videnskabelig evidens for  at de ikke virker  3  hvorfor går de ud fra  ansigtsmasker virker  når der er videnskabelig evidens for  at de ikke virker        ',
#  'denne mand drhuge lever af at give folk store muskler  han blev selv ramt af delta varianten  og hold nu fast  han tabte 13kg muskler pga  delta  hvis i ikke tror på mig  så gå ind på hans instagram og se hvor stor han har været for ikke længe siden  ',
#  'spoiler alert         ',
#  'hvis du møder mig fremover og gør klar til håndtryk så vil jeg desværre komme til at skuffe dig    jeg kommer ikke til at give håndtryk eller kram til folk endnu  selvom det nu er lovligt at gøre  åndtryk ',
#  'og vi gentager  delta gør at man ikke kan regne med at være undtaget fra at blive syg nok til både at blive indlagt og få langtidsvirkninger  selv om man er under 40   eller 30   eller 20  bliv vaccineret  både for din egen og dine omgivelsers skyld  ',
#  'status  tilslutningen til vaccinationsprogrammet mod covid 19 er tårnhøj  men der er blandt de 20 29 årige en lidt lavere tilslutning end i de andre grupper  vi har sat sejlene ind for at nå de 20 29 årige  der endnu ikke har booket tid   ',
#  'i underkanten af 64 000 stik i går  i går var endnu en dag med fokus på at genvaccinere folk  godt 57 500 2  stik vs  godt 6 200 1  stik     ',
#  'pressede betjente slår hårdest mød politiet med kærlighed og åbne arme     ',
#  '  så er det jo også “bedre” at tage til hartzen  har boet tre år i berlin  de to destinationer kan ikke sammenlignes  lærerne har hijacket turen  er det grundet covid19  hvordan det  &amp; hvorfor så   el bare fordi eleverne ville noget “forkert”   det lyder som om det er nye kriterier',
#  'der skrives meget om stigende smittetal i israel  men indtil videre er den nye bølge væsentligt anderledes end de forrige  hvad angår indlæggelser og dødsfald  værd at have in mente  selvom vi selvfølgelig skal diskutere behovet for en 3  dosis for visse grupper   ',
#  '  hvorfor skulle hartzen under covid19 være bedre end berlin   en rejse til de to steder kan ikke sammenlignes  hvad jeg ikke ved er om berlin nu   overhovedet er nær det almindelige berlin  men enig med   sommeren 2020 i berlin var dødsyg  håber det er bedre nu',
#  'opdateret status  uændret generelt billede for bivirkninger efter vaccination mod   langt de fleste bivirkninger er kendte og forbigående  de 12 15 årige udviser samme bivirkningsprofil som befolkningen som helhed  læs mere   ',
#  'opdateret status  uændret generelt billede for bivirkninger efter vaccination mod   langt de fleste bivirkninger er kendte og forbigående  de 12 15 årige udviser samme bivirkningsprofil som befolkningen som helhed  læs mere   ',
#  'israels massevaccination   25% stigning i hjertestop og hjerteanfald i alderen 16 29   86 6% stigning i hjerteanfald i alderen 20 29          ',
#  '“allerede i marts 2020 sendte mine samarbejdspartnere i kina mig e mails  hvor de fortalte  at de ikke længere kunne samarbejde med mig mere om sars cov 2’s oprindelse  fordi det simpelthen var blevet forbudt at forske i det uafhængigt”   ',
#  'der er drop in i dag kl  9 18 i alle vaccinationscentrene i    på bornholm er der drop in kl  9 16 i dag    ',
#  '4/7 ar sindikalourien ezed  ar benelourezed  an dispac’hourien ezed hag an demokrat ez ed a dle stourm asambles evit difenn en ur mod politikel ar gwir da vezañ vaksinet dre ar servij yec’hed    [   ]       ',
#  '1/n  det er en skandale  at der ikke er udført en systematisk undersøgelse af koagulationssystemsaktivering før vaccinegodkendelserne    og at de regulatoriske myndigheder har godkendt vaccinerne på trods af det        ',
#  '4/7 ar sindikalourien ezed  ar benelourezed  an dispac’hourien ezed hag an demokrat ez ed a dle stourm asambles evit difenn en ur mod politikel ar gwir da vezañ vaksinet dre ar servij yec’hed    [   ]       ',
#  'fordi man ikke skal holde afstand  betyder det ikke  at man ikke må  højeste antal smittede i 2 uger og højeste antal indlagte i 2 mdr  ifølge radioavisen lige nu  noget føles lidt off      ',
#  'svensk pandemistrategi i danske skoler  ikke med vores børn  ørnenemodcovid19    ',
#  '4/7 ar sindikalourien ezed  ar benelourezed  an dispac’hourien ezed hag an demokrat ez ed a dle stourm asambles evit difenn en ur mod politikel ar gwir da vezañ vaksinet dre ar servij yec’hed    [   ]       ',
#  'god info og forklaring på alt det fis der kører i rundgang  ',
#  'underlig nok  hvergang de begynder med ny vaccination så går det galt  nu er de igang med tredje stik  mon det er corona de bliver inficeret med gennem vaccine      israel er ulydig mod vorherre måske derfor   😇❤️🙏vi kan kun bede for dem  ',
#  'status  tilslutningen til vaccinationsprogrammet mod covid 19 er tårnhøj  men der er blandt de 20 29 årige en lidt lavere tilslutning end i de andre grupper  vi har sat sejlene ind for at nå de 20 29 årige  der endnu ikke har booket tid   ',
#  'og vi gentager  delta gør at man ikke kan regne med at være undtaget fra at blive syg nok til både at blive indlagt og få langtidsvirkninger  selv om man er under 40   eller 30   eller 20  bliv vaccineret  både for din egen og dine omgivelsers skyld  ',
#  '2/n  alle der beskæftiger sig med det her ved eller burde vide  at bl a  endothelceller udtrykker ace2          ',
#  '3/n  der er brug for en hurtig systematisk undersøgelse af d dimer profil efter vaccination for alle de betinget godkendte vacciner  f eks  baseline før  +1  +2  +3  +5 +7  +10  +14  +21 dage        ',
#  '4/n  og undersøgelsen kan fint med et tilstrækkeligt antal patienter udføres uden daglig ulejlighed for forsøspersonerne  f eks  med tre grupper  baseline  +3  +10 / +1  +5  +14 / +2  +7  +21         ',
#  '1/n  det er en skandale  at der ikke er udført en systematisk undersøgelse af koagulationssystemsaktivering før vaccinegodkendelserne    og at de regulatoriske myndigheder har godkendt vaccinerne på trods af det        ',
#  'samme problem på hawaii efter vaccination af befolkningen   det sammen kommet til at ske over alt   det starte som influenza sæsonen 2019 og vi ender med evig lockdown       ',
#  '"deltavarianten er det store problem uden løsning "   ',
#  'hvis  har haft en underdødelighed under  hysteriet  så er alle vel klar over hvad der højst sandsynligt venter til vinter   ',
#  'opdateret status  uændret generelt billede for bivirkninger efter vaccination mod   langt de fleste bivirkninger er kendte og forbigående  de 12 15 årige udviser samme bivirkningsprofil som befolkningen som helhed  læs mere   ',
#  'israel troede  de havde nedkæmpet coronavirussen   men trods omfattende vaccinationer tvinges landet nu til nye restriktioner og til at give tredje vaccine til mange borgere  deltavarianten er det store problem uden løsning     ',
#  'israel troede  de havde nedkæmpet coronavirussen   men trods omfattende vaccinationer tvinges landet nu til nye restriktioner og til at give tredje vaccine til mange borgere  deltavarianten er det store problem uden løsning     ',
#  'covid 19 smitter særlig meget ved sang indendørs ørnenemodcovid19  åren         ',
#  'og selvfølgelig er cepos med på den vogn  her bestyrelsesmedlem christian bjørnskov  skammeligt     ',
#  'primier  visiting   vaccination sites in saulsville attridgeville  ',
#  'opdateret status  uændret generelt billede for bivirkninger efter vaccination mod   langt de fleste bivirkninger er kendte og forbigående  de 12 15 årige udviser samme bivirkningsprofil som befolkningen som helhed  læs mere   ',
#  'primier  visiting   vaccination sites in saulsville attridgeville  ',
#  'direktør  har i dag vaccineret elever i pop up vaccinationscenteret på euc nordvestsjælland og slotshaven gymnasium i holbæk  det er en del af indsatsen for at øge vaccinationstilslutningen blandt unge  og tak til alle jer  der tog imod tilbuddet💪 ',
#  'stærkt  det er der virkelig behov for   ',
#  'dagens  tal d  12/8  der meldes i dag om 1 dødsfald  det giver 💛 fordi ugegennemsnittet er steget til 0 6 pr  dag  hvilket forhøjes til 1  der er ydermere 1 085 nye tilfælde  det er 19 ‰\xa0af de ca  57 000 tests  indlagte steget til 113  ihad  🔴🔴🔴💛  ',
#  'og vi gentager  delta gør at man ikke kan regne med at være undtaget fra at blive syg nok til både at blive indlagt og få langtidsvirkninger  selv om man er under 40   eller 30   eller 20  bliv vaccineret  både for din egen og dine omgivelsers skyld  ',
#  '  det er så dejligt og jeg nyder virkelig også at kunne komme der  hvad der er endnu mere vildt er  at der har stået haver tomme til den pris i årevis  det var først da covid19 kom og københavnerne fandt ud af  at de fandtes  at de blev lejet ud ',
#  '1/n  det er en skandale  at der ikke er udført en systematisk undersøgelse af koagulationssystemsaktivering før vaccinegodkendelserne    og at de regulatoriske myndigheder har godkendt vaccinerne på trods af det        ',
#  '  nu er dødeligheden for polio og covid19 ikke just 1 1 ',
#  'og selvfølgelig er cepos med på den vogn  her bestyrelsesmedlem christian bjørnskov  skammeligt     ',
#  'direktør  har i dag vaccineret elever i pop up vaccinationscenteret på euc nordvestsjælland og slotshaven gymnasium i holbæk  det er en del af indsatsen for at øge vaccinationstilslutningen blandt unge  og tak til alle jer  der tog imod tilbuddet💪 ',
#  'dybt uansvarligt og nærmest kriminel timing  situationen i florida og texas taget i betragtning  hvordan kan denne mand dog være en amerikansk senator    ',
#  '1/n  no surprise    se opsummering i tweet herunder af den kendte viden om ekspressionen af ace2 i forskellige organer    nyrerne er et af organsystemerne med høj ekspression          ',
#  'israels massevaccination   25% stigning i hjertestop og hjerteanfald i alderen 16 29   86 6% stigning i hjerteanfald i alderen 20 29          ',
#  'primier  visiting   vaccination sites in saulsville attridgeville  ',
#  'direktør  har i dag vaccineret elever i pop up vaccinationscenteret på euc nordvestsjælland og slotshaven gymnasium i holbæk  det er en del af indsatsen for at øge vaccinationstilslutningen blandt unge  og tak til alle jer  der tog imod tilbuddet💪 ',
#  'nogen der ved  hvor mange af de dagligt nye smittede med covid19 i dk  der er færdigvaccineret  ',
#  'covid 19 smitter særlig meget ved sang indendørs ørnenemodcovid19  åren         ',
#  'direktør  har i dag vaccineret elever i pop up vaccinationscenteret på euc nordvestsjælland og slotshaven gymnasium i holbæk  det er en del af indsatsen for at øge vaccinationstilslutningen blandt unge  og tak til alle jer  der tog imod tilbuddet💪 ',
#  'israelsk covid19 supermedicin  der behandler 90% af indlagte godt nok til at de kan forlade hospitalet                  ',
#  'i dag åbnede region sjælland det første af mange pop up vaccinationscentre ved en uddannelsesinstitution   hjalp med at vaccinere eleverne på euc nordvestsjælland i holbæk  stor tilslutning \xa0\xa0  ',
#  'dagens  tal d  12/8  der meldes i dag om 1 dødsfald  det giver 💛 fordi ugegennemsnittet er steget til 0 6 pr  dag  hvilket forhøjes til 1  der er ydermere 1 085 nye tilfælde  det er 19 ‰\xa0af de ca  57 000 tests  indlagte steget til 113  ihad  🔴🔴🔴💛  ',
#  'frivilligt   hvis folk ønsker  er jeg sikker på  de kan henvende sig  stop det    27 pct  har ikke reageret på vaccineinvitation  sundhedsstyrelsen opruster for at få særlig gruppe til at tage vaccinen          ',
#  '3/n  der er brug for en hurtig systematisk undersøgelse af d dimer profil efter vaccination for alle de betinget godkendte vacciner  f eks  baseline før  +1  +2  +3  +5 +7  +10  +14  +21 dage        ',
#  '1/n  det er en skandale  at der ikke er udført en systematisk undersøgelse af koagulationssystemsaktivering før vaccinegodkendelserne    og at de regulatoriske myndigheder har godkendt vaccinerne på trods af det        ',
#  '1/n  no surprise    se opsummering i tweet herunder af den kendte viden om ekspressionen af ace2 i forskellige organer    nyrerne er et af organsystemerne med høj ekspression          ',
#  'primier  visiting   vaccination sites in saulsville attridgeville  ',
#  'ja men så må de 4 5 6 ……… 🥴     ',
#  'og vi gentager  delta gør at man ikke kan regne med at være undtaget fra at blive syg nok til både at blive indlagt og få langtidsvirkninger  selv om man er under 40   eller 30   eller 20  bliv vaccineret  både for din egen og dine omgivelsers skyld  ',
#  'og vi gentager  delta gør at man ikke kan regne med at være undtaget fra at blive syg nok til både at blive indlagt og få langtidsvirkninger  selv om man er under 40   eller 30   eller 20  bliv vaccineret  både for din egen og dine omgivelsers skyld  ',
#  'og vi gentager  delta gør at man ikke kan regne med at være undtaget fra at blive syg nok til både at blive indlagt og få langtidsvirkninger  selv om man er under 40   eller 30   eller 20  bliv vaccineret  både for din egen og dine omgivelsers skyld  ',
#  'i underkanten af 64 000 stik i går  i går var endnu en dag med fokus på at genvaccinere folk  godt 57 500 2  stik vs  godt 6 200 1  stik     ',
#  'dagens  tal d  12/8  der meldes i dag om 1 dødsfald  det giver 💛 fordi ugegennemsnittet er steget til 0 6 pr  dag  hvilket forhøjes til 1  der er ydermere 1 085 nye tilfælde  det er 19 ‰\xa0af de ca  57 000 tests  indlagte steget til 113  ihad  🔴🔴🔴💛  ',
#  'i underkanten af 64 000 stik i går  i går var endnu en dag med fokus på at genvaccinere folk  godt 57 500 2  stik vs  godt 6 200 1  stik     ',
#  'gad vide om indlæggelsestallene også afspejler sygeplejerskenes  indtil nu  glemte strejke   noget må jo ske for at lægge pres på   mystisk at så mange indlægges om sommeren   ',
#  '1/n  det er en skandale  at der ikke er udført en systematisk undersøgelse af koagulationssystemsaktivering før vaccinegodkendelserne    og at de regulatoriske myndigheder har godkendt vaccinerne på trods af det        ',
#  'status  tilslutningen til vaccinationsprogrammet mod covid 19 er tårnhøj  men der er blandt de 20 29 årige en lidt lavere tilslutning end i de andre grupper  vi har sat sejlene ind for at nå de 20 29 årige  der endnu ikke har booket tid   ',
#  '1/3  breaking  nye corona tal i dk    positive tests seneste døgn  1085  i går  1162  tests  pcr  seneste døgn  57072  gns  7 dage  62483  positiv %  pcr  seneste døgn  1 9  gns  7 dage  1 57  døde seneste døgn  1  i alt  2555   kilde   ',
#  'jeg blev færdigvaccineret i går 🎉💉   selvom jeg ikke er så aktiv herinde for tiden  så slipper i ikke for et post vaccinefejrings selfie📸    ',
#  'der er drop in i dag kl  9 18 i alle vaccinationscentrene i    på bornholm er der drop in kl  9 16 i dag    ',
#  'status  tilslutningen til vaccinationsprogrammet mod covid 19 er tårnhøj  men der er blandt de 20 29 årige en lidt lavere tilslutning end i de andre grupper  vi har sat sejlene ind for at nå de 20 29 årige  der endnu ikke har booket tid   ',
#  '  det var da godt nok pudsigt  når befolkningen bliver tvunget til at bruge den     ',
#  ...]

# %%
stop_words_list = nltk.corpus.stopwords.words("danish")

sent_sw_removed = [i for i in nltk.word_tokenize(tweets) if i not in stop_words_list]
sent_sw_removed
# Out:
# ['Beder',
#  'indberette',
#  'tweet',
#  ',',
#  'tydeligt',
#  'opfordrer',
#  'overgreb',
#  ',',
#  'tvang',
#  'vold',
#  'børn',
#  'unge',
#  '.',
#  'Bør',
#  'høre',
#  'hjemme',
#  'sociale',
#  'medier',
#  '#',
#  'coronadk',
#  '#',
#  'dkmedier',
#  '#',
#  'dkpol',
#  '#',
#  'covid19dk',
#  '@',
#  'SSTbrostrom',
#  '@',
#  'Heunicke',
#  'monstre',
#  'skabt',
#  '?',
#  'https',
#  ':',
#  '//t.co/Ido6EZf2EC']

# %%
#Taking out emojis
emoji = emoji_pattern.sub(r'', str(clean_data))

#Tokenizing the data 
sent = nltk.tokenize.word_tokenize(emoji)

#Remove danish stopWords
stopWords = set(stopwords.words('danish'))
wordsFiltered = []

for w in sent:
    if w not in stopWords:
        wordsFiltered.append(w)

# %%
sent
# Out:
# ['[',
#  "'",
#  'b',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'a',
#  "'",
#  ',',
#  "'",
#  'l',
#  "'",
#  ',',
#  "'",
#  'l',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'i',
#  "'",
#  ',',
#  "'n",
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'b',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  'w',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'a',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  'y',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'l',
#  "'",
#  ',',
#  "'",
#  'i',
#  "'",
#  ',',
#  "'",
#  'g',
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'p',
#  "'",
#  ',',
#  "'",
#  'f',
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  'i',
#  "'",
#  ',',
#  "'",
#  'l',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'v',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  'g',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'b',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  'v',
#  "'",
#  ',',
#  "'",
#  'a',
#  "'",
#  ',',
#  "'n",
#  "'",
#  ',',
#  "'",
#  'g',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'g',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'v',
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'l',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'m",
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'b',
#  "'",
#  ',',
#  "'",
#  'ø',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'n",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'g',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'u',
#  "'",
#  ',',
#  "'n",
#  "'",
#  ',',
#  "'",
#  'g',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'b',
#  "'",
#  ',',
#  "'",
#  'ø',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'i',
#  "'",
#  ',',
#  "'",
#  'k',
#  "'",
#  ',',
#  "'",
#  'k',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'h',
#  "'",
#  ',',
#  "'",
#  'ø',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'h',
#  "'",
#  ',',
#  "'",
#  'j',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'m",
#  "'",
#  ',',
#  "'m",
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'p',
#  "'",
#  ',',
#  "'",
#  'å',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'s",
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'c',
#  "'",
#  ',',
#  "'",
#  'i',
#  "'",
#  ',',
#  "'",
#  'a',
#  "'",
#  ',',
#  "'",
#  'l',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'m",
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'i',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  '#',
#  "'",
#  ',',
#  "'",
#  'c',
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'n",
#  "'",
#  ',',
#  "'",
#  'a',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'k',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  '#',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'k',
#  "'",
#  ',',
#  "'m",
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'i',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  '#',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'k',
#  "'",
#  ',',
#  "'",
#  'p',
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'l',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  '#',
#  "'",
#  ',',
#  "'",
#  'c',
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'v',
#  "'",
#  ',',
#  "'",
#  'i',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  '1',
#  "'",
#  ',',
#  "'",
#  '9',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'k',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  '@',
#  "'",
#  ',',
#  "'s",
#  "'",
#  ',',
#  "'s",
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  'b',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'s",
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'m",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  '@',
#  "'",
#  ',',
#  "'",
#  'h',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'u',
#  "'",
#  ',',
#  "'n",
#  "'",
#  ',',
#  "'",
#  'i',
#  "'",
#  ',',
#  "'",
#  'c',
#  "'",
#  ',',
#  "'",
#  'k',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'h',
#  "'",
#  ',',
#  "'",
#  'v',
#  "'",
#  ',',
#  "'",
#  'a',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'f',
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'n",
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  'g',
#  "'",
#  ',',
#  "'",
#  'l',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'m",
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'n",
#  "'",
#  ',',
#  "'s",
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'i',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'h',
#  "'",
#  ',',
#  "'",
#  'a',
#  "'",
#  ',',
#  "'",
#  'r',
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'s",
#  "'",
#  ',',
#  "'",
#  'k',
#  "'",
#  ',',
#  "'",
#  'a',
#  "'",
#  ',',
#  "'",
#  'b',
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'h',
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  'p',
#  "'",
#  ',',
#  "'s",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'/",
#  "'",
#  ',',
#  "'/",
#  "'",
#  ',',
#  "'t",
#  "'",
#  ',',
#  "'",
#  "'",
#  ',',
#  "'",
#  'c',
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'/",
#  "'",
#  ',',
#  "'",
#  'i',
#  "'",
#  ',',
#  "'d",
#  "'",
#  ',',
#  "'",
#  'o',
#  "'",
#  ',',
#  "'",
#  '6',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'z',
#  "'",
#  ',',
#  "'",
#  'f',
#  "'",
#  ',',
#  "'",
#  '2',
#  "'",
#  ',',
#  "'",
#  'e',
#  "'",
#  ',',
#  "'",
#  'c',
#  "'",
#  ']']

# %%
# has only been lower-cased and tokenized (a few cells above)
d = defaultdict(int)
for i in wordsFiltered:
    for w in i:
        d[w]+=1
V = d.keys()
print("Vocabulary size:",len(V))

# inspect the 10 most frequent tokens:
{k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)[:10]}
# Out:
# Vocabulary size: 177
